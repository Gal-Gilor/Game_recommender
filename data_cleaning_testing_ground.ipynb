# %%
import pandas as pd
import re
import numpy as np
from tqdm import tqdm
import numpy as np
import json

# %%
df = pd.read_json('raw_data.json', lines=True)
df.head()
# Out:
#       id                         name  rating  \
# 0   3498           Grand Theft Auto V    4.48
# 1   4200                     Portal 2    4.61
# 2   3328     The Witcher 3: Wild Hunt    4.68
# 3   5679  The Elder Scrolls V: Skyrim    4.39
# 4  12020                Left 4 Dead 2    4.08
#
#                                              ratings    released  metacritic  \
# 0  [{'id': 5, 'title': 'exceptional', 'count': 16...  2013-09-17        96.0
# 1  [{'id': 5, 'title': 'exceptional', 'count': 16...  2011-04-19        95.0
# 2  [{'id': 5, 'title': 'exceptional', 'count': 20...  2015-05-18        93.0
# 3  [{'id': 5, 'title': 'exceptional', 'count': 10...  2011-11-11         NaN
# 4  [{'id': 4, 'title': 'recommended', 'count': 76...  2009-11-17        89.0
#
#    ratings_count             genres
# 0           2758  [Action, Shooter]
# 1           2405  [Shooter, Puzzle]
# 2           2552              [RPG]
# 3           2015      [Action, RPG]
# 4           1431  [Action, Shooter]

# %%
print(f'{df.describe()}\n')
print(f'{df.info()}\n')
print(f"released NA {df['released'].isna().sum()}\n")
print(f"metacritic NA {df['metacritic'].isna().sum()}\n")
# Out:
#                   id        rating   metacritic  ratings_count
# count   11298.000000  11298.000000  2271.000000   11298.000000
# mean    34967.389715      2.717164    73.616028      54.676226
# std     57025.162227      1.504177    10.458881     144.520690
# min         2.000000      0.000000    24.000000       4.000000
# 25%     10665.500000      2.000000    68.000000       6.000000
# 50%     19600.500000      3.250000    75.000000      13.000000
# 75%     38375.500000      3.870000    81.000000      36.000000
# max    394092.000000      5.000000    97.000000    2758.000000
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11298 entries, 0 to 11297
# Data columns (total 8 columns):
# id               11298 non-null int64
# name             11298 non-null object
# rating           11298 non-null float64
# ratings          11298 non-null object
# released         11088 non-null object
# metacritic       2271 non-null float64
# ratings_count    11298 non-null int64
# genres           11298 non-null object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 706.2+ KB
# None
#
# released NA 210
#
# metacritic NA 9027

# %%
df[df.released.isna()].sort_values(by='ratings_count', ascending=False).head(23)
# Out:
#           id                                          name  rating  \
# 226     5687                                  The Playroom    2.21
# 548    42309                         Dead Island: Epidemic    2.20
# 794    42391                                       Nosgoth    2.54
# 1491   10096                                        3DMark    3.43
# 1247   23576                        GOD EATER RESURRECTION    3.20
# 2516    9551                            Deep Rock Galactic    4.14
# 2104   10156           Aliens: Colonial Marines Collection    2.60
# 4212    5673                          Terminator Salvation    2.70
# 807    18785        Sam & Max 303: They Stole Max's Brain!    2.76
# 3325   11587                                        Kenshi    4.16
# 812    18786  Sam & Max 304: Beyond the Alley of the Dolls    2.76
# 814    18783                 Sam & Max 301: The Penal Zone    2.84
# 811    18787  Sam & Max 305: The City That Dares Not Sleep    2.81
# 813    18784         Sam & Max 302: The Tomb of Sammun-Mak    2.81
# 2396   19678                   Sword of the Stars: The Pit    3.31
# 3891   28832                                     Kinect Me    2.62
# 2399   11665              SpellForce 2 Anniversary Edition    3.55
# 5326   61549                       中国式家长 / Chinese Parents    3.83
# 4281   46301                                          Raft    3.57
# 2506   16131                            Dragon Nest Europe    2.59
# 5799  275629                                       Unheard    4.11
# 1149   18848                             Hector: Episode 1    2.44
# 1167   18849                             Hector: Episode 2    2.38
#
#                                                 ratings released  metacritic  \
# 226   [{'id': 1, 'title': 'skip', 'count': 210, 'per...     None         NaN
# 548   [{'id': 1, 'title': 'skip', 'count': 63, 'perc...     None         NaN
# 794   [{'id': 1, 'title': 'skip', 'count': 40, 'perc...     None         NaN
# 1491  [{'id': 4, 'title': 'recommended', 'count': 44...     None         NaN
# 1247  [{'id': 3, 'title': 'meh', 'count': 28, 'perce...     None         NaN
# 2516  [{'id': 4, 'title': 'recommended', 'count': 40...     None         NaN
# 2104  [{'id': 1, 'title': 'skip', 'count': 21, 'perc...     None        45.0
# 4212  [{'id': 3, 'title': 'meh', 'count': 21, 'perce...     None         NaN
# 807   [{'id': 1, 'title': 'skip', 'count': 13, 'perc...     None         NaN
# 3325  [{'id': 5, 'title': 'exceptional', 'count': 16...     None         NaN
# 812   [{'id': 1, 'title': 'skip', 'count': 13, 'perc...     None         NaN
# 814   [{'id': 1, 'title': 'skip', 'count': 12, 'perc...     None         NaN
# 811   [{'id': 1, 'title': 'skip', 'count': 12, 'perc...     None         NaN
# 813   [{'id': 1, 'title': 'skip', 'count': 12, 'perc...     None         NaN
# 2396  [{'id': 4, 'title': 'recommended', 'count': 14...     None        68.0
# 3891  [{'id': 3, 'title': 'meh', 'count': 16, 'perce...     None         NaN
# 2399  [{'id': 4, 'title': 'recommended', 'count': 12...     None        80.0
# 5326  [{'id': 4, 'title': 'recommended', 'count': 22...     None         NaN
# 4281  [{'id': 4, 'title': 'recommended', 'count': 16...     None         NaN
# 2506  [{'id': 1, 'title': 'skip', 'count': 10, 'perc...     None         NaN
# 5799  [{'id': 4, 'title': 'recommended', 'count': 20...     None         NaN
# 1149  [{'id': 1, 'title': 'skip', 'count': 11, 'perc...     None         NaN
# 1167  [{'id': 1, 'title': 'skip', 'count': 11, 'perc...     None         NaN
#
#       ratings_count                                      genres
# 226             441                                          []
# 548             136                                    [Arcade]
# 794              97                           [Action, Shooter]
# 1491             79                                          []
# 1247             71                                    [Action]
# 2516             61                             [Action, Indie]
# 2104             54                                    [Action]
# 4212             40                           [Action, Shooter]
# 807              38                                 [Adventure]
# 3325             38  [Action, RPG, Strategy, Simulation, Indie]
# 812              37                                 [Adventure]
# 814              37                         [Action, Adventure]
# 811              36                                 [Adventure]
# 813              36                                 [Adventure]
# 2396             32              [RPG, Strategy, Casual, Indie]
# 3891             29                                          []
# 2399             29                     [Action, RPG, Strategy]
# 5326             28            [RPG, Simulation, Casual, Indie]
# 4281             28                                 [Adventure]
# 2506             27        [Action, RPG, Massively Multiplayer]
# 5799             27                    [RPG, Simulation, Indie]
# 1149             27                                          []
# 1167             26                         [Adventure, Casual]

# %% [markdown]
# # Cleaning the dataset
#     1. Filling or removing missing values
#     2. Save the new dataset to a new file

# %%
# check which game is missing release date and manually fill those with over 30 votes
def add_release_dates(df):
    '''
    This function fills specific observations with specific release dates.
    Input:
        df: Original raw data dataframe
    Output:
        Partially filled release dates in the dataframe
    '''
    # star wars: obi wan
    df.at[11169, 'released'] = '2001-12-19'
    # god eater resurrection
    df.at[1247, 'released'] = '2015-10-29' 
    # deep rock galactic
    df.at[2516, 'released'] = '2018-02-28'
    # aliens: Colonial Marines Collection
    df.at[2104, 'released'] = '2013-02-12'
    # terminator Salvation
    df.at[4212, 'released'] = '2009-05-01'
    # kenshi
    df.at[3325, 'released'] = '2018-12-06'
    # Sam & Max 303: They Stole Max's Brain!
    df.at[807, 'released'] = '2010-06-22'
    # Sam & Max 303: Beyond the Alley of the Dolls
    df.at[812, 'released'] = '2010-07-20'
    # Sam & Max 303: The Penal Zone
    df.at[814, 'released'] = '2010-04-02'
    # Sam & Max 303: The City That Dares Not Sleep
    df.at[811, 'released'] = '2010-08-30'
    # Sam & Max 303:  The Tomb of Sammun-Mak
    df.at[813, 'released'] = '2010-05-18'
    # Sword of the Stars: The Pit
    df.at[2396, 'released'] = '2013-02-21'
    # SpellForce 2 Anniversary Edition
    df.at[2399, 'released'] = '2017-04-12'
    # raft
    df.at[4281, 'released'] = '2018-05-23'
    # Unheard
    df.at[5799, 'released'] = '2019-03-29'
    # Hector: Episode 2
    df.at[1167, 'released'] = '2011-06-25'
    
    # most of the games with higher vote count that are missing release date are closed/suspended
    # no use recommending them.
    df.dropna(subset=['released'], inplace=True)
    return df

df = add_release_dates(df)

# drop games that do not contain genres
df = df[df['genres'].map(lambda x: len(x) > 0)]

# asses the NAN value situation
print(f'{df.metacritic.isna().sum()}\n')
print(f'{df.info()}/n')
# Out:
# 8255
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10509 entries, 0 to 11297
# Data columns (total 8 columns):
# id               10509 non-null int64
# name             10509 non-null object
# rating           10509 non-null float64
# ratings          10509 non-null object
# released         10509 non-null object
# metacritic       2254 non-null float64
# ratings_count    10509 non-null int64
# genres           10509 non-null object
# dtypes: float64(2), int64(2), object(4)
# memory usage: 738.9+ KB
# None/n

# %% [markdown]
# # Filling the metacritic scores for as many games as possible
#     1. Retrieve the names of all games without metacritic score
#     2. Use selenium to scrape scores

# %%
no_metacritic = np.array(df['name'][df['metacritic'].isna()])
# no_metacritic.to_csv('missing_metacritic.csv', index=False)
# no_metacritic.tail()

# %%
from selenium import webdriver
import requests

# %%
def to_json(dictionary, filename):
    '''
    Input:
        game: dictionary containing the data to write to the file
        filename: a string stating the name and path you wish to save the file at
    Returns:
        json file
    '''
    with open(f'{filename}.json', 'a') as file:
            file.write(f'{json.dumps(dictionary)}\n')
    return

# %%
def scrape_metacritic(names, filename):
    '''
    Input:
        names: list of games to scrape their score from metacritic
        filename: a string for saving the json file
    Returns:
        json file containing a list of dictionarys with the name of the game and the 
    '''
    scores = []
    for name in tqdm(names):
        game = {}
        # open metacritic
        driver = webdriver.Chrome()
        driver.get("https://www.metacritic.com/game")
        driver.implicitly_wait(14)
        
        try:
            # find search bar to search the, enter the game name, and click search
            driver.find_element_by_id('primary_search_box').send_keys(f'{name}')
            driver.implicitly_wait(2)
            driver.find_element_by_id('primary_menu_item_enter_search').click()

            # filter out non games
            driver.implicitly_wait(6)
            parent = driver.find_element_by_class_name("filter_area")
            driver.implicitly_wait(2)
            element = parent.find_elements_by_class_name("title")[2].click()
            
            # good reviews
            if driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game positive"][1])'):
                driver.implicitly_wait(0.5)
                score = driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game positive"][1])')[0].text
            
            # no review yet
            elif driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game tbd"][1])'):
                driver.implicitly_wait(0.5)
                score = driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game tbd"][1])')[0].text
            
            # mixed reviews
            elif driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game mixed"][1])'):
                driver.implicitly_wait(0.5)
                score = driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game mixed"][1])')[0].text
            
            # bad reviews
            elif driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game negative"][1])'):
                driver.implicitly_wait(0.5)
                score = driver.find_elements_by_xpath('(.//span[@class = "metascore_w medium game negative"][1])')[0].text
            
            else:
                score = "Not Found"             
        except:
            score = "Selenium Fail" 
        
        game[name] = score
        to_json(game, filename)
        scores.append(game)    
        driver.close()
    
    driver.quit()
    return scores
 
metacritic_scores = scrape_metacritic(no_metacritic[:2], 'test')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:51<00:00, 25.82s/it]

# %%
metacritic_scores
# Out:
# [{'The Elder Scrolls V: Skyrim': '84'}, {'Half-Life 2: Lost Coast': 'tbd'}]

# %%
games = requests.get('https://api.rawg.io/api/games?page=1').json()
games['results'][0]
# Out:
# {'id': 3498,
#  'slug': 'grand-theft-auto-v',
#  'name': 'Grand Theft Auto V',
#  'released': '2013-09-17',
#  'tba': False,
#  'background_image': 'https://media.rawg.io/media/games/b11/b115b2bc6a5957a917bc7601f4abdda2.jpg',
#  'rating': 4.47,
#  'rating_top': 5,
#  'ratings': [{'id': 5,
#    'title': 'exceptional',
#    'count': 1652,
#    'percent': 58.23},
#   {'id': 4, 'title': 'recommended', 'count': 966, 'percent': 34.05},
#   {'id': 3, 'title': 'meh', 'count': 175, 'percent': 6.17},
#   {'id': 1, 'title': 'skip', 'count': 44, 'percent': 1.55}],
#  'ratings_count': 2814,
#  'reviews_text_count': 14,
#  'added': 9794,
#  'added_by_status': {'yet': 169,
#   'owned': 6334,
#   'beaten': 2311,
#   'toplay': 291,
#   'dropped': 390,
#   'playing': 299},
#  'metacritic': 96,
#  'playtime': 70,
#  'suggestions_count': 401,
#  'user_game': None,
#  'reviews_count': 2837,
#  'saturated_color': '0f0f0f',
#  'dominant_color': '0f0f0f',
#  'platforms': [{'platform': {'id': 4,
#     'name': 'PC',
#     'slug': 'pc',
#     'image': None,
#     'year_end': None,
#     'year_start': None,
#     'games_count': 194905,
#     'image_background': 'https://media.rawg.io/media/games/bc0/bc06a29ceac58652b684deefe7d56099.jpg'},
#    'released_at': '2013-09-17',
#    'requirements_en': {'minimum': 'Minimum:OS: Windows 10 64 Bit, Windows 8.1 64 Bit, Windows 8 64 Bit, Windows 7 64 Bit Service Pack 1, Windows Vista 64 Bit Service Pack 2* (*NVIDIA video card recommended if running Vista OS)Processor: Intel Core 2 Quad CPU Q6600 @ 2.40GHz (4 CPUs) / AMD Phenom 9850 Quad-Core Processor (4 CPUs) @ 2.5GHzMemory: 4 GB RAMGraphics: NVIDIA 9800 GT 1GB / AMD HD 4870 1GB (DX 10, 10.1, 11)Storage: 72 GB available spaceSound Card: 100% DirectX 10 compatibleAdditional Notes: Over time downloadable content and programming changes will change the system requirements for this game.  Please refer to your hardware manufacturer and www.rockstargames.com/support for current compatibility information. Some system components such as mobile chipsets, integrated, and AGP graphics cards may be incompatible. Unlisted specifications may not be supported by publisher.     Other requirements:  Installation and online play requires log-in to Rockstar Games Social Club (13+) network; internet connection required for activation, online play, and periodic entitlement verification; software installations required including Rockstar Games Social Club platform, DirectX , Chromium, and Microsoft Visual C++ 2008 sp1 Redistributable Package, and authentication software that recognizes certain hardware attributes for entitlement, digital rights management, system, and other support purposes.     SINGLE USE SERIAL CODE REGISTRATION VIA INTERNET REQUIRED; REGISTRATION IS LIMITED TO ONE ROCKSTAR GAMES SOCIAL CLUB ACCOUNT (13+) PER SERIAL CODE; ONLY ONE PC LOG-IN ALLOWED PER SOCIAL CLUB ACCOUNT AT ANY TIME; SERIAL CODE(S) ARE NON-TRANSFERABLE ONCE USED; SOCIAL CLUB ACCOUNTS ARE NON-TRANSFERABLE.  Partner Requirements:  Please check the terms of service of this site before purchasing this software.',
#     'recommended': 'Recommended:OS: Windows 10 64 Bit, Windows 8.1 64 Bit, Windows 8 64 Bit, Windows 7 64 Bit Service Pack 1Processor: Intel Core i5 3470 @ 3.2GHz (4 CPUs) / AMD X8 FX-8350 @ 4GHz (8 CPUs)Memory: 8 GB RAMGraphics: NVIDIA GTX 660 2GB / AMD HD 7870 2GBStorage: 72 GB available spaceSound Card: 100% DirectX 10 compatibleAdditional Notes:'},
#    'requirements_ru': None},
#   {'platform': {'id': 18,
#     'name': 'PlayStation 4',
#     'slug': 'playstation4',
#     'image': None,
#     'year_end': None,
#     'year_start': None,
#     'games_count': 4339,
#     'image_background': 'https://media.rawg.io/media/games/f99/f9979698c43fd84c3ab69280576dd3af.jpg'},
#    'released_at': '2013-09-17',
#    'requirements_en': None,
#    'requirements_ru': None},
#   {'platform': {'id': 16,
#     'name': 'PlayStation 3',
#     'slug': 'playstation3',
#     'image': None,
#     'year_end': None,
#     'year_start': None,
#     'games_count': 3548,
#     'image_background': 'https://media.rawg.io/media/games/af7/af7a831001c5c32c46e950cc883b8cb7.jpg'},
#    'released_at': '2013-09-17',
#    'requirements_en': None,
#    'requirements_ru': None},
#   {'platform': {'id': 14,
#     'name': 'Xbox 360',
#     'slug': 'xbox360',
#     'image': None,
#     'year_end': None,
#     'year_start': None,
#     'games_count': 2479,
#     'image_background': 'https://media.rawg.io/media/games/198/1988a337305e008b41d7f536ce9b73f6.jpg'},
#    'released_at': '2013-09-17',
#    'requirements_en': None,
#    'requirements_ru': None},
#   {'platform': {'id': 1,
#     'name': 'Xbox One',
#     'slug': 'xbox-one',
#     'image': None,
#     'year_end': None,
#     'year_start': None,
#     'games_count': 2953,
#     'image_background': 'https://media.rawg.io/media/games/088/088b41ca3f9d22163e43be07acf42304.jpg'},
#    'released_at': '2013-09-17',
#    'requirements_en': None,
#    'requirements_ru': None}],
#  'parent_platforms': [{'platform': {'id': 1, 'name': 'PC', 'slug': 'pc'}},
#   {'platform': {'id': 2, 'name': 'PlayStation', 'slug': 'playstation'}},
#   {'platform': {'id': 3, 'name': 'Xbox', 'slug': 'xbox'}}],
#  'genres': [{'id': 4,
#    'name': 'Action',
#    'slug': 'action',
#    'games_count': 77821,
#    'image_background': 'https://media.rawg.io/media/games/81b/81b138691f027ed1f8720758daa0d895.jpg'},
#   {'id': 2,
#    'name': 'Shooter',
#    'slug': 'shooter',
#    'games_count': 21725,
#    'image_background': 'https://media.rawg.io/media/games/328/3283617cb7d75d67257fc58339188742.jpg'}],
#  'stores': [{'id': 290375,
#    'store': {'id': 3,
#     'name': 'PlayStation Store',
#     'slug': 'playstation-store',
#     'domain': 'store.playstation.com',
#     'games_count': 6045,
#     'image_background': 'https://media.rawg.io/media/games/929/9295e55ce69cf5337c567983cf8b4137.jpeg'},
#    'url_en': 'https://store.playstation.com/en-us/product/UP1004-CUSA00419_00-GTAVDIGITALDOWNL',
#    'url_ru': 'https://store.playstation.com/ru-ru/product/EP1004-CUSA00411_00-GTAVDIGITALDOWNL'},
#   {'id': 290378,
#    'store': {'id': 2,
#     'name': 'Xbox Store',
#     'slug': 'xbox-store',
#     'domain': 'microsoft.com',
#     'games_count': 2589,
#     'image_background': 'https://media.rawg.io/media/games/088/088b41ca3f9d22163e43be07acf42304.jpg'},
#    'url_en': 'https://www.microsoft.com/en-us/store/p/grand-theft-auto-v/bpj686w6s0nh?cid=msft_web_chart',
#    'url_ru': None},
#   {'id': 290377,
#    'store': {'id': 7,
#     'name': 'Xbox 360 Store',
#     'slug': 'xbox360',
#     'domain': 'marketplace.xbox.com',
#     'games_count': 1758,
#     'image_background': 'https://media.rawg.io/media/games/4a0/4a0a1316102366260e6f38fd2a9cfdce.jpg'},
#    'url_en': 'https://marketplace.xbox.com/en-US/Product/GTA-V/66acd000-77fe-1000-9115-d802545408a7',
#    'url_ru': None},
#   {'id': 290376,
#    'store': {'id': 1,
#     'name': 'Steam',
#     'slug': 'steam',
#     'domain': 'store.steampowered.com',
#     'games_count': 39740,
#     'image_background': 'https://media.rawg.io/media/games/8e0/8e032ac4faf1136e7d708bb3ac61af23.jpg'},
#    'url_en': 'http://store.steampowered.com/app/271590/',
#    'url_ru': None}],
#  'clip': {'clip': 'https://media.rawg.io/media/stories-640/5b0/5b0cfff8c606c5e4db4f74f108c4413b.mp4',
#   'clips': {'320': 'https://media.rawg.io/media/stories-320/91d/91d6b5963064a5f686f635c302095b55.mp4',
#    '640': 'https://media.rawg.io/media/stories-640/5b0/5b0cfff8c606c5e4db4f74f108c4413b.mp4',
#    'full': 'https://media.rawg.io/media/stories/f64/f64ce0b857918b0c202f2a5d3217848e.mp4'},
#   'video': 'dZubIhK-Z6w',
#   'preview': 'https://media.rawg.io/media/stories-previews/f65/f6593df6c8df32c7f4763f9cb112a514.jpg'},
#  'short_screenshots': [{'id': -1,
#    'image': 'https://media.rawg.io/media/games/b11/b115b2bc6a5957a917bc7601f4abdda2.jpg'},
#   {'id': 1827219,
#    'image': 'https://media.rawg.io/media/screenshots/1b4/1b4eefb4cc2a77d4d35bb4a6926f3189.jpg'},
#   {'id': 1827221,
#    'image': 'https://media.rawg.io/media/screenshots/a7c/a7c43871a54bed6573a6a429451564ef.jpg'},
#   {'id': 1827222,
#    'image': 'https://media.rawg.io/media/screenshots/cf4/cf4367daf6a1e33684bf19adb02d16d6.jpg'},
#   {'id': 1827223,
#    'image': 'https://media.rawg.io/media/screenshots/f95/f9518b1d99210c0cae21fc09e95b4e31.jpg'},
#   {'id': 1827224,
#    'image': 'https://media.rawg.io/media/screenshots/2dc/2dc7ea94641f7329d177f228564b968a.jpg'},
#   {'id': 1827225,
#    'image': 'https://media.rawg.io/media/screenshots/a5c/a5c95ea539c87d5f538763e16e18fb99.jpg'}]}

# %%
b = df[type(df['genres']) != 'list' ]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-100-f9aec9cefcae> in <module>
# ----> 1 b = df[type(df['genres']) != 'list' ]
#
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2993             if self.columns.nlevels > 1:
#    2994                 return self._getitem_multilevel(key)
# -> 2995             indexer = self.columns.get_loc(key)
#    2996             if is_integer(indexer):
#    2997                 indexer = [indexer]
#
# ~\Anaconda3\envs\py36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
# -> 2899                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2900         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2901         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True

# %%
df
# Out:
#            id                           name  rating  \
# 0        3498             Grand Theft Auto V    4.48
# 1        4200                       Portal 2    4.61
# 2        3328       The Witcher 3: Wild Hunt    4.68
# 3        5679    The Elder Scrolls V: Skyrim    4.39
# 4       12020                  Left 4 Dead 2    4.08
# ...       ...                            ...     ...
# 11293   27504  Sonic Boom: Shattered Crystal    0.00
# 11294    5899                 Temple Run: Oz    0.00
# 11295   32329                    Nitemare-3D    0.00
# 11296  394092                        Bemuzed    0.00
# 11297  299546                 Swing the Ball    4.12
#
#                                                  ratings    released  \
# 0      [{'id': 5, 'title': 'exceptional', 'count': 16...  2013-09-17
# 1      [{'id': 5, 'title': 'exceptional', 'count': 16...  2011-04-19
# 2      [{'id': 5, 'title': 'exceptional', 'count': 20...  2015-05-18
# 3      [{'id': 5, 'title': 'exceptional', 'count': 10...  2011-11-11
# 4      [{'id': 4, 'title': 'recommended', 'count': 76...  2009-11-17
# ...                                                  ...         ...
# 11293  [{'id': 1, 'title': 'skip', 'count': 3, 'perce...  2014-11-11
# 11294  [{'id': 4, 'title': 'recommended', 'count': 2,...  2013-03-05
# 11295  [{'id': 1, 'title': 'skip', 'count': 2, 'perce...  1994-01-01
# 11296  [{'id': 5, 'title': 'exceptional', 'count': 5,...  2019-11-22
# 11297  [{'id': 4, 'title': 'recommended', 'count': 7,...  2019-02-20
#
#        metacritic  ratings_count                genres
# 0            96.0           2758     [Action, Shooter]
# 1            95.0           2405     [Shooter, Puzzle]
# 2            93.0           2552                 [RPG]
# 3             NaN           2015         [Action, RPG]
# 4            89.0           1431     [Action, Shooter]
# ...           ...            ...                   ...
# 11293         NaN              4                    []
# 11294         NaN              4   [Action, Adventure]
# 11295         NaN              4     [Action, Shooter]
# 11296         NaN              4  [Puzzle, Platformer]
# 11297         NaN              6       [Casual, Indie]
#
# [11104 rows x 8 columns]

# %%
a = []
len(a)
# Out:
# 0

# %%
pd.DataFrame(data, index=data.keys())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-114-940a593e88e2> in <module>
# ----> 1 pd.DataFrame(data, index=data.keys())
#
# AttributeError: 'list' object has no attribute 'keys'

# %%
df.genres[11293]
# Out:
# []

# %%
df.ratings[0]
# Out:
# [{'id': 5, 'title': 'exceptional', 'count': 1620, 'percent': 58.25},
#  {'id': 4, 'title': 'recommended', 'count': 947, 'percent': 34.05},
#  {'id': 3, 'title': 'meh', 'count': 173, 'percent': 6.22},
#  {'id': 1, 'title': 'skip', 'count': 41, 'percent': 1.47}]

# %%
raw_scores_df = pd.read_csv('test.csv')
raw_scores_df.head()
# Out:
#    name
# 0    82

# %%
raw_scores_df = pd.read_json('metacritic_scores.json', lines=True)
def fill_metacritic(df, scores_df, column):
    
    # create a single column df with all the scraped data found on the diagonal
    scores_df.set_index([scores_df.columns], inplace=True)
    scores_df = pd.DataFrame(np.diag(scores_df), index=scores_df.index, columns=['metacritic'])
    
    # fill the missing results from the scraped scores by index
    df.set_index(column, inplace=True)
    df.metacritic = df['metacritic'].fillna(scores_df['metacritic'])
    return df

# %%
scores_df.reset_index()
# Out:
#                                              metacritic
# The Elder Scrolls V: Skyrim                          84
# Half-Life 2: Lost Coast                             tbd
# Metro 2033                                           90
# Warframe                                             86
# God of War                                Selenium Fail
# ...                                                 ...
# Organ Trail: Director's Cut                          86
# Warhammer 40,000: Eternal Crusade         Selenium Fail
# NARUTO SHIPPUDEN: Ultimate Ninja STORM 4             79
# Star Saviors                                  Not Found
# Katana ZERO                               Selenium Fail
#
# [600 rows x 1 columns]

# %%
cleaned_df = df.copy(deep=True)
cleaned_df.to_csv('cleaner_raw_data.csv')

# %%
uniques = pd.unique(cleaned_df['Genres'].values.ravel('K'))
uniques[0][0]

# %%
def add_genre_columns(df, column):
    # convert the strings in genres column to list
    df, uniques = str_tolist(df, column)
    
    #create dataframe with the column names
    genres_df = pd.DataFrame(columns=uniques)
    
    # join the original df with the new df
    df = df.join(column_df, how='left')
    
    # add function that uses the list strings to fill the values
    return df, list_strings

def fill_genre_columns(df, uniques):
    df2 = df.copy(deep=True)
    zeros = np.zeros(len(uniques))
    
    all_dummies = []
    for row in tqdm(df2.itertuples()):
        i = 1
        uniques_dic = dict(zip(uniques, zeros))
        while i < len(uniques):
            if row in uniques:
                uniques_dic[row[i]] = 1
                i += 1

        all_dummies.append(uniques_dic)
    return pd.DataFrame(all_dummies, columns=uniques)
    
df, uniques = add_genre_columns(cleaned_df, 'Genres')

# %%
test = cleaned_df.copy(deep=True)

# %%
def populate_df(df):
    """ This function turns the characters dataframe into dummy varaibles dataframe"""
    uniques = pd.unique(df.values.ravel('K'))
    zeros = np.zeros(len(uniques))

    # main df protection
    df = df.copy(deep=True)

    all_dummies = []
    for row in df.itertuples():
        i = 1
        uniques_dic = dict(zip(uniques, zeros))
        while i < 6:
            uniques_dic[row[i]] = 1
            i += 1

        all_dummies.append(uniques_dic)
    return pd.DataFrame(all_dummies, columns=uniques)

# %%
import re

df3 = cleaned_df['Genres'].str.replace(r'\']', '')
df3 = pd.DataFrame(df3.str.split().values.tolist())
df3[0] = df3[0].str.replace(r'[', '')
df3[0] = df3[0].str.replace(r'\'', '')
df3[0] = df3[0].str.replace(r'\,', '')

df3
# df2 = cleaned_df.copy(deep=True)
# zeros = np.zeros(len(uniques))

# if any("abc" in s for s in some_list):

test_df = df2.join(df3, how='left')

i = 0
for row in tqdm(test_df.itertuples()):
    print(f'{row}\n')
    uniques_dic = dict(zip(uniques, zeros))
    print(f'{uniques_dic}\n')
    while i < len(uniques):
            if any(row in unique for unique in uniques):
                uniques_dic[row[i]] = 1
                i += 1
                if i == 20:
                    break
    break

# %%
def create_genre_list(series):
    genre_list = []
    for genres in series:
        genre_list.append(genres)
    return genre_list

a = create_genre_list(genres_series)
type(a[-1])

# %%
with open('metacritic_scores.json', 'r') as file:
    dude = [json.loads(f) for f in file]

dude
# Out:
# [{'The Elder Scrolls V: Skyrim': '84'},
#  {'Half-Life 2: Lost Coast': 'tbd'},
#  {'Metro 2033': '90'},
#  {'Warframe': '86'},
#  {'God of War': 'Selenium Fail'},
#  {'Red Dead Redemption 2': '97'},
#  {'Horizon Zero Dawn': 'Selenium Fail'},
#  {'Half-Life 2: Deathmatch': 'tbd'},
#  {'Batman: Arkham Knight': 'Selenium Fail'},
#  {'Uncharted 4: A Thief’s End': 'Not Found'},
#  {'Half-Life Deathmatch: Source': 'tbd'},
#  {"Garry's Mod": 'tbd'},
#  {'Bloodborne': '92'},
#  {"Marvel's Spider-Man": '87'},
#  {'Assassin’s Creed IV Black Flag': 'Not Found'},
#  {'The Walking Dead': '89'},
#  {'BioShock Remastered': 'tbd'},
#  {'Viscera Cleanup Detail: Shadow Warrior': 'tbd'},
#  {'The Walking Dead: Season 1': '87'},
#  {'PlayerUnknown’s Battlegrounds': 'Not Found'},
#  {'Red Dead Redemption': '97'},
#  {'Heavy Rain': '78'},
#  {'Dead Island': '80'},
#  {'Paladins': 'Selenium Fail'},
#  {'SEGA Mega Drive and Genesis Classics': 'tbd'},
#  {'Detroit: Become Human': '78'},
#  {'Metro 2033 Redux': '90'},
#  {'Darksiders Warmastered Edition': '81'},
#  {"Assassin's Creed II": '91'},
#  {'BioShock 2 Remastered': 'tbd'},
#  {'Deus Ex: Human Revolution': '90'},
#  {'Hollow Knight': '90'},
#  {'Unturned': 'tbd'},
#  {'Quake Champions': 'tbd'},
#  {'Castle Crashers': '83'},
#  {'The Last Of Us': '95'},
#  {'inFAMOUS Second Son': '80'},
#  {'South Park: The Stick of Truth': '85'},
#  {'NieR:Automata': 'Not Found'},
#  {"Oddworld: Abe's Oddysee": '84'},
#  {'Monster Hunter: World': '90'},
#  {'Injustice: Gods Among Us Ultimate Edition': '80'},
#  {'Half-Life: Opposing Force': 'Selenium Fail'},
#  {'Darksiders II': '84'},
#  {'STAR WARS - Knights of the Old Republic': '93'},
#  {'Grand Theft Auto: Episodes from Liberty City': 'tbd'},
#  {"Tom Clancy's Rainbow Six Siege": '79'},
#  {'Tom Clancy’s The Division': 'Not Found'},
#  {'Batman: Arkham City': '96'},
#  {'Until Dawn': '79'},
#  {'The Walking Dead: Season 2': '83'},
#  {'Game of Thrones - A Telltale Games Series': 'tbd'},
#  {'Call of Duty: Modern Warfare 3': '92'},
#  {'Serious Sam Fusion 2017 (beta)': 'Not Found'},
#  {'Jet Set Radio': '88'},
#  {'Far Cry 5': '81'},
#  {'DiRT Showdown': '75'},
#  {'GRID': '87'},
#  {'Team Fortress Classic': 'tbd'},
#  {"Assassin's Creed Unity": 'tbd'},
#  {'Killer is Dead - Nightmare Edition': '71'},
#  {'BEYOND: Two Souls': '78'},
#  {'Titan Quest Anniversary Edition': 'tbd'},
#  {'Watch Dogs 2': 'Selenium Fail'},
#  {'Dust: An Elysian Tail': '85'},
#  {'Ori and the Blind Forest': '88'},
#  {'Tales from the Borderlands': '86'},
#  {'Hotline Miami 2: Wrong Number': '75'},
#  {'Ratchet & Clank (2016)': 'Not Found'},
#  {'Apex Legends': '88'},
#  {'Cuphead': '88'},
#  {'Half-Life: Source': 'tbd'},
#  {'Brawlhalla': 'tbd'},
#  {'Battlefield 4': 'Selenium Fail'},
#  {'Valiant Hearts: The Great War': '77'},
#  {'Batman: Arkham Asylum': '91'},
#  {'Borderlands Game of the Year Enhanced': 'Not Found'},
#  {"Assassin's Creed Odyssey": '83'},
#  {'Resident Evil 4': '81'},
#  {'Rust': '75'},
#  {'Sleeping Dogs: Definitive Edition': '77'},
#  {'Crysis 2 - Maximum Edition': 'tbd'},
#  {'Resident Evil 7: Biohazard': '86'},
#  {'Sekiro: Shadows Die Twice': 'Selenium Fail'},
#  {'FINAL FANTASY XV': '85'},
#  {'Dragon Age: Inquisition': '89'},
#  {'The Binding of Isaac: Rebirth': '88'},
#  {'Kingdom Come: Deliverance': '76'},
#  {'LEGO The Hobbit': 'Selenium Fail'},
#  {'Hitman 2': '82'},
#  {'Viking: Battle for Asgard': '65'},
#  {'Metro: Last Light': '82'},
#  {'Heroes & Generals': 'tbd'},
#  {'Death Stranding': '82'},
#  {'Deponia: The Complete Journey': 'tbd'},
#  {'STAR WARS Battlefront': 'Selenium Fail'},
#  {'Battlefield 3': '88'},
#  {'The Order: 1886': '63'},
#  {'Dead Cells': '89'},
#  {'The Elder Scrolls Online: Tamriel Unlimited': '77'},
#  {'Darksiders II Deathinitive Edition': '75'},
#  {'Call of Duty: Modern Warfare Remastered': '83'},
#  {"Assassin's Creed": '81'},
#  {'God of War III Remastered': 'Selenium Fail'},
#  {'Fortnite: Save The World': 'Not Found'},
#  {'Shadow of the Tomb Raider': '75'},
#  {'Resident Evil Revelations 2 / Biohazard Revelations 2': 'Not Found'},
#  {'Titan Quest': '77'},
#  {'Mortal Kombat Komplete Edition': '81'},
#  {'The Long Dark': 'Selenium Fail'},
#  {'Mass Effect 3': '94'},
#  {'Dying Light': '86'},
#  {'Robocraft': 'tbd'},
#  {'Devil May Cry 5': '88'},
#  {'Call of Duty: WWII': '79'},
#  {'Ricochet': 'Selenium Fail'},
#  {'Minecraft': 'Selenium Fail'},
#  {'Deathmatch Classic': 'tbd'},
#  {'Battlerite': '85'},
#  {'X-COM: UFO Defense': 'tbd'},
#  {'Minion Masters': 'tbd'},
#  {'Clicker Heroes': 'tbd'},
#  {'Bulletstorm': '75'},
#  {'FINAL FANTASY XIII': '83'},
#  {'Doki Doki Literature Club!': '78'},
#  {'Unreal Gold': 'tbd'},
#  {'H1Z1: King of the Kill': 'Not Found'},
#  {'The Awesome Adventures of Captain Spirit': '75'},
#  {'Subnautica': '87'},
#  {'LittleBigPlanet 3': '79'},
#  {'inFAMOUS First Light': '73'},
#  {'The Expendabros': 'tbd'},
#  {'Diablo III: Reaper of Souls': '87'},
#  {'The Banner Saga': '80'},
#  {'Mass Effect: Andromeda': '76'},
#  {'ARK: Survival Of The Fittest': 'tbd'},
#  {'Forza Horizon 4': 'Selenium Fail'},
#  {'Valkyria Chronicles': '84'},
#  {'Halo: The Master Chief Collection': '85'},
#  {'Trove': '91'},
#  {'Guns of Icarus Alliance': 'tbd'},
#  {'Command & Conquer: Red Alert 3 - Uprising': '64'},
#  {'Resident Evil 2': '81'},
#  {'Dear Esther: Landmark Edition': 'tbd'},
#  {'Stealth Inc 2: A Game of Clones': '77'},
#  {'Dark Souls': '84'},
#  {'Totally Accurate Battlegrounds': 'tbd'},
#  {'Dota Underlords': 'tbd'},
#  {'DiRT 3': '86'},
#  {'Celeste': '92'},
#  {'Everlasting Summer': 'tbd'},
#  {'Max Payne 2: The Fall of Max Payne': '86'},
#  {'Condemned: Criminal Origins': '78'},
#  {'Superbrothers: Sword & Sworcery EP': '83'},
#  {'Sniper Elite 3': '78'},
#  {'Trackmania Turbo': '81'},
#  {'Metro Exodus': '80'},
#  {'Fable III': '80'},
#  {'No More Room in Hell': 'tbd'},
#  {'This is the Police': 'tbd'},
#  {'Her Story': '86'},
#  {'Killzone Shadow Fall': '73'},
#  {'The Outer Worlds': '85'},
#  {'RaceRoom Racing Experience': 'tbd'},
#  {'Gears of War': '84'},
#  {'Need for Speed': '80'},
#  {'Red Faction Guerrilla Re-Mars-tered': '70'},
#  {'AdVenture Capitalist': 'tbd'},
#  {'Final Fantasy VII': '92'},
#  {'ARMA: Cold War Assault': 'tbd'},
#  {'Dead Island Riptide': 'tbd'},
#  {'Trine 2': '84'},
#  {'BIT.TRIP RUNNER': '87'},
#  {'Quake Live': 'tbd'},
#  {'Sunset Overdrive': 'Selenium Fail'},
#  {'The Forest': '83'},
#  {'Gears of War 2': '94'},
#  {'Dark Souls: Remastered': '84'},
#  {'Total War: SHOGUN 2': '90'},
#  {'Besiege': 'Selenium Fail'},
#  {'Warhammer 40,000: Dawn of War II: Retribution': '80'},
#  {'Pixel Puzzles Ultimate': 'tbd'},
#  {'A Way Out': '78'},
#  {'The Elder Scrolls IV: Oblivion': '94'},
#  {'Halo 3': '94'},
#  {'Warhammer: Vermintide 2': '82'},
#  {'Resident Evil': '86'},
#  {'LittleBigPlanet': '79'},
#  {'The Ship: Single Player': 'Not Found'},
#  {'STAR WARS - Dark Forces': '91'},
#  {'Never Alone (Kisima Ingitchuna)': 'Not Found'},
#  {'Need for Speed Rivals': '80'},
#  {'Hero Siege': '80'},
#  {'Cyberpunk 2077': 'tbd'},
#  {'Knights and Merchants': 'tbd'},
#  {'VRChat': 'tbd'},
#  {'Gears 5': '84'},
#  {'Halo: Reach': '91'},
#  {'Overlord: Raising Hell': 'tbd'},
#  {'Costume Quest': '77'},
#  {'Receiver': 'tbd'},
#  {'FIFA 18': '84'},
#  {'Burnout Paradise': '82'},
#  {'Dungeon Defenders II': 'tbd'},
#  {'World of Tanks': '80'},
#  {"Tom Clancy's Ghost Recon Wildlands": '76'},
#  {'Defy Gravity Extended': 'tbd'},
#  {'ORION: Prelude': 'Not Found'},
#  {'Plague Inc: Evolved': '80'},
#  {'Hitman: Sniper Challenge': '80'},
#  {'Out There Somewhere': 'tbd'},
#  {'Hitman 3: Contracts': '74'},
#  {'DuckTales: Remastered': '78'},
#  {'7 Days to Die': 'tbd'},
#  {'No Time To Explain Remastered': 'Selenium Fail'},
#  {'Fahrenheit: Indigo Prophecy Remastered': '76'},
#  {'Control': '82'},
#  {'Nioh': '88'},
#  {'Crash Bandicoot': '78'},
#  {'Kingdom: New Lands': '87'},
#  {'Serious Sam Classics: Revolution': 'tbd'},
#  {'Realm Royale': 'tbd'},
#  {"Q.U.B.E: Director's Cut": '76'},
#  {'Mortal Kombat': '85'},
#  {'Sacred 2 Gold': 'tbd'},
#  {'Unravel': '77'},
#  {'Gears of War 3': '86'},
#  {'Gun Monkeys': 'tbd'},
#  {'NBA 2K16': '87'},
#  {'Tomb Raider II': '76'},
#  {'inFAMOUS 2': '83'},
#  {'Slay the Spire': '89'},
#  {'Gears of War 4': '84'},
#  {'FIFA 15': '82'},
#  {'Flower': '91'},
#  {'Battlefield Hardline': 'tbd'},
#  {'Tabletop Simulator': 'tbd'},
#  {'Worms Battlegrounds': '62'},
#  {'Need for Speed: Most Wanted - A Criterion Game': '78'},
#  {'Tom Clancy’s Splinter Cell Blacklist': 'Not Found'},
#  {'Really Big Sky': 'Selenium Fail'},
#  {'Swords and Soldiers HD': '78'},
#  {'Space Engineers': 'tbd'},
#  {'Fable Anniversary': 'tbd'},
#  {'Star Wars Jedi: Fallen Order': '80'},
#  {'Conan Exiles': 'tbd'},
#  {'Rebel Galaxy': '75'},
#  {'Crash Bandicoot 3: Warped': '91'},
#  {'Worms Armageddon': '84'},
#  {'Hexic HD': '79'},
#  {'Banished': 'tbd'},
#  {'METAL SLUG 3': '76'},
#  {'Ring of Elysium': 'tbd'},
#  {'Frostpunk': '84'},
#  {'Magicka: Wizard Wars': '69'},
#  {'Crash Bandicoot 2: Cortex Strikes Back': 'Not Found'},
#  {'Crazy Taxi (1999)': 'Selenium Fail'},
#  {'STAR WARS Empire at War - Gold Pack': 'tbd'},
#  {'LittleBigPlanet 2': '91'},
#  {'Dungeon Siege 3': '86'},
#  {'Days Gone': 'tbd'},
#  {'Counter-Strike Nexon: Zombies': 'tbd'},
#  {'Trine': '84'},
#  {"Hellblade: Senua's Sacrifice VR Edition": '87'},
#  {'Resident Evil 7 / Biohazard 7 Teaser: Beginning Hour': 'Not Found'},
#  {'God of War III': '92'},
#  {'inFamous': '80'},
#  {'Dead Bits': 'tbd'},
#  {'Trine 3: The Artifacts of Power': '65'},
#  {"Sam & Max 303: They Stole Max's Brain!": 'Not Found'},
#  {'Back to the Future: Ep 4 - Double Visions': 'Not Found'},
#  {'Back to the Future: Ep 3 - Citizen Brown': 'Not Found'},
#  {'Back to the Future: Ep 2 - Get Tannen!': 'Not Found'},
#  {'Sam & Max 305: The City That Dares Not Sleep': 'Not Found'},
#  {'Sam & Max 304: Beyond the Alley of the Dolls': 'Not Found'},
#  {'Sam & Max 302: The Tomb of Sammun-Mak': 'Not Found'},
#  {'Sam & Max 301: The Penal Zone': 'Selenium Fail'},
#  {'Back to the Future: Ep 5 - OUTATIME': '75'},
#  {'Commandos: Behind Enemy Lines': 'tbd'},
#  {"That's You!": '83'},
#  {'LEGO Batman 2 DC Super Heroes': '81'},
#  {'Woodle Tree Adventures': 'tbd'},
#  {'God of War II': 'Selenium Fail'},
#  {'UNCHARTED: Golden Abyss': '80'},
#  {'Murderous Pursuits': '63'},
#  {'Fable II': '89'},
#  {'Braveland': 'tbd'},
#  {"The Beginner's Guide": '76'},
#  {"Demon's Souls": '89'},
#  {'Cry of Fear': 'tbd'},
#  {'Crysis 2': 'Selenium Fail'},
#  {'Pyre': '85'},
#  {'FIFA 14': '87'},
#  {'Hammerfight': 'tbd'},
#  {'Knack': 'tbd'},
#  {'Resident Evil 2 (1998)': 'tbd'},
#  {'Wasteland': '87'},
#  {'EA SPORTS FIFA 16': 'Not Found'},
#  {'Into the Breach': 'Selenium Fail'},
#  {'RESOGUN': '84'},
#  {'Mutant Year Zero: Road to Eden': '76'},
#  {'Gorky 17': 'Not Found'},
#  {'Halo 5: Guardians': '84'},
#  {'Magic Duels': '77'},
#  {'BEEP': 'tbd'},
#  {'Mortal Kombat 11': '81'},
#  {'Forza Horizon 3': '91'},
#  {'Gwent: The Witcher Card Game': '80'},
#  {'Crossout': 'Selenium Fail'},
#  {'Fishing Planet': 'tbd'},
#  {'Sonic CD': 'Selenium Fail'},
#  {"Mirror's Edge Catalyst": 'Selenium Fail'},
#  {"Assassin's Creed Freedom Cry": '76'},
#  {'Commandos: Beyond the Call of Duty': 'tbd'},
#  {'Geneshift': 'tbd'},
#  {'Northgard': '80'},
#  {'Lost Planet 3': '61'},
#  {"King's Quest": '82'},
#  {'Survarium': 'tbd'},
#  {'The Whispered World Special Edition': 'tbd'},
#  {'Warhammer 40,000: Dawn of War - Soulstorm': '73'},
#  {'Metal Gear Solid 4: Guns of the Patriots': '94'},
#  {'Onrush': '75'},
#  {'Battlefield V': 'Selenium Fail'},
#  {'A Hat in Time': '79'},
#  {'Eets Munchies': 'Selenium Fail'},
#  {'Yet Another Zombie Defense': 'tbd'},
#  {'Deceit': 'tbd'},
#  {'Crash Time 2': 'tbd'},
#  {'Sea of Thieves': '69'},
#  {'Halo 4': '87'},
#  {'E.Y.E: Divine Cybermancy': '61'},
#  {'KnightShift': 'tbd'},
#  {'I’m not a Monster': 'Not Found'},
#  {'Tacoma': '79'},
#  {'Worms': '83'},
#  {'Gran Turismo Sport': '75'},
#  {"Sonic Adventure DX Director's Cut": 'tbd'},
#  {'FIFA 19': '83'},
#  {'Vampyr': '75'},
#  {'Relic Hunters Zero': 'tbd'},
#  {'Streamline': 'tbd'},
#  {'APB Reloaded': 'tbd'},
#  {'Warhammer 40,000: Dawn of War – Winter Assault': '85'},
#  {'KILLER IS DEAD': 'tbd'},
#  {'Doom 3: BFG Edition': '67'},
#  {'Dr. Langeskov, The Tiger, and The Terribly Cursed Emerald: A Whirlwind Heist': 'tbd'},
#  {'Retro City Rampage DX': '91'},
#  {'Fistful of Frags': 'tbd'},
#  {'One Finger Death Punch': '82'},
#  {'Dead Space 3': '86'},
#  {'Darksiders III': 'tbd'},
#  {'Dead Rising': '78'},
#  {'Moonlighter': '81'},
#  {'Table Top Racing: World Tour': '75'},
#  {'Spyro Reignited Trilogy': '82'},
#  {'STAR WARS Jedi Knight - Mysteries of the Sith': 'tbd'},
#  {'Resident Evil 0 / biohazard 0 HD REMASTER': 'Not Found'},
#  {'Gravity Rush': '80'},
#  {'Beyond Good & Evil': '83'},
#  {'DayZ': 'tbd'},
#  {'Sonic Adventure 2': '89'},
#  {'Call of Duty: Black Ops 4': '83'},
#  {'Dragon Age 2': '86'},
#  {'Skyborn': 'tbd'},
#  {'Black Squad': 'Selenium Fail'},
#  {'Catherine': 'Selenium Fail'},
#  {"Broken Sword: Shadow of the Templars - The Director's Cut": 'Selenium Fail'},
#  {'Warface': 'tbd'},
#  {'Overcast - Walden and the Werewolf': 'tbd'},
#  {'Polarity': 'tbd'},
#  {'Emily is Away': 'Selenium Fail'},
#  {'Plants vs. Zombies': '81'},
#  {'Castlevania: Lords of Shadow – Ultimate Edition': '81'},
#  {'Mark of the Ninja: Remastered': '89'},
#  {'Devil May Cry 4: Special Edition': '75'},
#  {'Ni no Kuni: Wrath of the White Witch': '86'},
#  {'CRYSIS 3': '91'},
#  {'Titanfall': '89'},
#  {'Just Cause 2: Multiplayer Mod': 'Not Found'},
#  {'Alienation': '79'},
#  {'CONSORTIUM': 'tbd'},
#  {'World of Guns: Gun Disassembly': 'tbd'},
#  {'Happy Wars': 'tbd'},
#  {'Kingdom Hearts III': '83'},
#  {'Cuisine Royale': 'tbd'},
#  {'TrackMania Nations Forever': 'tbd'},
#  {'Velocity 2X': '87'},
#  {'The Unfinished Swan': '83'},
#  {'The Lab': '77'},
#  {'Ni no Kuni II: Revenant Kingdom': '84'},
#  {'CounterSpy': '67'},
#  {'The Culling Of The Cows': 'tbd'},
#  {'Grand Theft Auto 2 (1999)': 'Not Found'},
#  {'The Silent Age': '84'},
#  {'X-COM: Terror From the Deep': 'tbd'},
#  {'Surviving Mars': '76'},
#  {'Particula': 'tbd'},
#  {'Grimm': '77'},
#  {'Fearless Fantasy': '84'},
#  {'Knowledge is Power': 'Selenium Fail'},
#  {'Jak and Daxter: The Precursor Legacy': '90'},
#  {'Serena': 'Selenium Fail'},
#  {'Killer Instinct': '86'},
#  {'The Elder Scrolls: Legends': '80'},
#  {'Factorio': 'tbd'},
#  {'Legend of Grimrock 2': 'Not Found'},
#  {'X-COM: Apocalypse': 'tbd'},
#  {'Alien Swarm: Reactive Drop': 'tbd'},
#  {'Gris': 'tbd'},
#  {'Tom Clancy’s The Division 2': 'Not Found'},
#  {'Borderlands 3': '78'},
#  {'Breath of Death VII': 'tbd'},
#  {'FINAL FANTASY XIII-2': '79'},
#  {'GTR Evolution': '83'},
#  {'FORCED': 'tbd'},
#  {'TIS-100': 'tbd'},
#  {'Gotham City Impostors': '65'},
#  {'SingStar': '82'},
#  {'Kabounce': 'tbd'},
#  {'PlayStation All-Stars Battle Royale': '75'},
#  {'Realms of the Haunting': 'tbd'},
#  {'Broken Sword 2 - the Smoking Mirror: Remastered': 'Selenium Fail'},
#  {'Quake II (1997)': 'Not Found'},
#  {'Deus Ex: Human Revolution - The Missing Link': '78'},
#  {'Serious Sam Double D XXL': 'tbd'},
#  {'Sven Co-op': 'tbd'},
#  {"Oddworld: Stranger's Wrath": '83'},
#  {'Spacelords': 'tbd'},
#  {'A Plague Tale: Innocence': 'Selenium Fail'},
#  {'Grand Theft Auto (1998)': 'Not Found'},
#  {'Samorost 2': 'tbd'},
#  {'Ultimate Doom': 'tbd'},
#  {'X-COM: Interceptor': 'tbd'},
#  {'RAGE 2': '81'},
#  {'GameGuru': 'tbd'},
#  {'God of War (2005)': 'Not Found'},
#  {'Street Racing Syndicate': 'tbd'},
#  {'Titan Attacks!': 'tbd'},
#  {'Hector: Episode 2': '83'},
#  {'Resident Evil (2002)': 'Not Found'},
#  {'12 is Better Than 6': 'tbd'},
#  {'Forza Horizon 2': '86'},
#  {'Morphopolis': 'tbd'},
#  {'The Basement Collection': 'tbd'},
#  {'Knights of Pen and Paper +1 Edition': 'Not Found'},
#  {'Painkiller: Black Edition': 'Not Found'},
#  {'SimCity 4 Deluxe Edition': 'Selenium Fail'},
#  {'ASTRONEER': 'tbd'},
#  {'Overgrowth': 'Not Found'},
#  {'The Walking Dead: Michonne': '82'},
#  {'MX vs. ATV Reflex': '75'},
#  {'Pixel Piracy': 'tbd'},
#  {'Duke Nukem 3D: Megaton Edition': 'tbd'},
#  {"Deadlight: Director's Cut": 'tbd'},
#  {'Argo': 'Selenium Fail'},
#  {'Worms Crazy Golf': '85'},
#  {'Type:Rider': 'Not Found'},
#  {'Life is Strange 2': '76'},
#  {'Lara Croft GO': '84'},
#  {'Legacy of Kain: Soul Reaver': '91'},
#  {'Cook, Serve, Delicious!': '85'},
#  {'This War of Mine: The Little Ones': '78'},
#  {'VA-11 Hall-A: Cyberpunk Bartender Action': '77'},
#  {'Guacamelee!': '83'},
#  {'Finding Paradise': '81'},
#  {'Zeno Clash 2': '65'},
#  {'Evoland 2': '76'},
#  {'State of Decay: YOSE': 'Not Found'},
#  {'Oxygen Not Included': 'tbd'},
#  {'Dishonored Definitive Edition': '80'},
#  {'Crackdown': '83'},
#  {'Planetary Annihilation: TITANS': 'tbd'},
#  {'RimWorld': 'Selenium Fail'},
#  {'Driver San Francisco': '80'},
#  {'Cities XL Platinum': 'tbd'},
#  {'Persona 4 Golden': '93'},
#  {'Revolution Ace': 'tbd'},
#  {'2064: Read Only Memories': '76'},
#  {'Halo Waypoint': 'tbd'},
#  {'GOD EATER RESURRECTION': 'tbd'},
#  {'The Howler': 'tbd'},
#  {'Anthem': 'tbd'},
#  {'Tomb Raider: The Angel of Darkness': '52'},
#  {'DLC Quest': 'tbd'},
#  {'Dead Island Definitive Edition': 'tbd'},
#  {'Iconoclasts': '87'},
#  {'FINAL FANTASY VIII': '90'},
#  {'Pinball Arcade': '82'},
#  {'State of Decay 2': 'Selenium Fail'},
#  {'Titan Quest: Immortal Throne': '80'},
#  {'SNOW': 'tbd'},
#  {'Project Zomboid': 'tbd'},
#  {'Tomb Raider IV: The Last Revelation': 'Not Found'},
#  {'Jetpack Joyride': '90'},
#  {'App Game Kit: Easy Game Development': 'Not Found'},
#  {'Super Smash Bros. Ultimate': '93'},
#  {'Return Of The Obra Dinn': 'Selenium Fail'},
#  {'Sid Meier’s Ace Patrol': 'Not Found'},
#  {'Sound Shapes': '84'},
#  {'PAC-MAN Championship Edition DX+': 'Not Found'},
#  {'The LEGO Movie - Videogame': '80'},
#  {'Camera Obscura': 'tbd'},
#  {'Gears of War: Ultimate Edition': '82'},
#  {'Creativerse': 'tbd'},
#  {'Sid Meier’s Ace Patrol: Pacific Skies': 'Not Found'},
#  {'Toki Tori 2+': '75'},
#  {'Warcraft 3: The Frozen Throne': '88'},
#  {'Forza Horizon': '91'},
#  {'Sky Force Anniversary': '77'},
#  {'ReCore': 'tbd'},
#  {'Forza Motorsport 5': '79'},
#  {'Wolfenstein 3D': '77'},
#  {'Transmissions: Element 120': 'Selenium Fail'},
#  {'Gauntlet': 'tbd'},
#  {'Dead Nation': '77'},
#  {'Castlevania: Lords of Shadow': '85'},
#  {'Ultra Street Fighter IV': '82'},
#  {'The Walking Dead: A New Frontier': '81'},
#  {'Ticket to Ride': '91'},
#  {'Skyforge': 'Selenium Fail'},
#  {'Master Levels for Doom II': 'tbd'},
#  {'Canyon Capers': 'tbd'},
#  {'Tomb Raider V: Chronicles': 'Not Found'},
#  {'Memories of a Vagabond': 'tbd'},
#  {'The Adventures of Shuggy': '77'},
#  {'Batman: Arkham Origins Blackgate - Deluxe Edition': 'tbd'},
#  {'Endorlight': 'tbd'},
#  {'Source Filmmaker': 'Not Found'},
#  {'Toribash': 'tbd'},
#  {"Viscera Cleanup Detail: Santa's Rampage": 'tbd'},
#  {'DRAGON BALL FighterZ': '87'},
#  {'Arma 2: DayZ Mod': 'Not Found'},
#  {'Worms Pinball': 'tbd'},
#  {'Tree of Savior (English Ver.)': 'Not Found'},
#  {'DETOUR': '76'},
#  {'Gravity Rush Remastered': '80'},
#  {'Portal Stories: Mel': 'tbd'},
#  {'Assassin’s Creed Chronicles: China': 'Not Found'},
#  {'Time Gentlemen, Please!': '84'},
#  {'Minit': '79'},
#  {'Faerie Solitaire': 'tbd'},
#  {'Blockstorm': 'Selenium Fail'},
#  {'Enslaved: Odyssey to the West': '80'},
#  {'theHunter': '75'},
#  {"Dragon's Crown": '80'},
#  {'Turbo Pug DX': 'tbd'},
#  {'Chaos Domain': 'tbd'},
#  {"Oddworld: Abe's Exoddus": '88'},
#  {'Batman': '87'},
#  {'LEGO Batman 3: Beyond Gotham': 'tbd'},
#  {'Beneath a Steel Sky': '82'},
#  {'The 39 Steps': 'tbd'},
#  {'ARMA: Gold Edition': 'tbd'},
#  {'Stick Fight: The Game': 'tbd'},
#  {'DiRT 2': '75'},
#  {'Q.U.B.E.': '76'},
#  {'Lost Castle': 'tbd'},
#  {'Mountain': '87'},
#  {'Caster': '77'},
#  {'Betrayer': '82'},
#  {'GOD EATER 2 Rage Burst': 'tbd'},
#  {'Hyperdrive Massacre': 'tbd'},
#  {'Squishy the Suicidal Pig': 'tbd'},
#  {"D4: Dark Dreams Don't Die": '76'},
#  {'Faerie Solitaire Remastered': 'tbd'},
#  {'Transformice': 'tbd'},
#  {'Darwin Project - Open Beta': 'Not Found'},
#  {'Evolvation': 'tbd'},
#  {'FIFA 12': '89'},
#  {'Anachronox': '77'},
#  {'Wizard of Legend': '76'},
#  {'English Country Tune': '78'},
#  {'PixelJunk Shooter Ultimate': '82'},
#  {'Laser League': '82'},
#  {'Gran Turismo 5': '84'},
#  {'The Deer': 'tbd'},
#  {'Prismata': 'tbd'},
#  {'Hacker Evolution': 'Selenium Fail'},
#  {"Broken Sword 5 - the Serpent's Curse": 'Not Found'},
#  {'TRANSFORMERS: Devastation': '77'},
#  {"Heroine's Quest: The Herald of Ragnarok": 'tbd'},
#  {'Bridge Constructor': '77'},
#  {'Final DOOM': 'tbd'},
#  {'The Orange Box': '96'},
#  {'Timberman': 'Selenium Fail'},
#  {'Guacamelee! 2': '83'},
#  {'You Have to Win the Game': 'tbd'},
#  {'Double Action: Boogaloo': 'tbd'},
#  {'The Sims 4': '81'},
#  {'Litil Divil': 'tbd'},
#  {'Killzone 2': '91'},
#  {"Bad Rats: the Rats' Revenge": 'tbd'},
#  {'Gear Up': 'tbd'},
#  {'Bloodstained: Ritual of the Night': 'Selenium Fail'},
#  {"Organ Trail: Director's Cut": '86'},
#  {'Warhammer 40,000: Eternal Crusade': 'Selenium Fail'},
#  {'NARUTO SHIPPUDEN: Ultimate Ninja STORM 4': '79'},
#  {'Star Saviors': 'Not Found'},
#  {'Katana ZERO': 'Selenium Fail'},
#  {'Burnout Paradise Remastered': '82'},
#  {'AER - Memories of Old': '70'},
#  {'Evoland Legendary Edition': 'tbd'},
#  {'8BitBoy': 'tbd'},
#  {'Hacker Evolution Duality': 'tbd'},
#  {'The Playroom VR': '77'},
#  {'Gears of War: Judgment': '79'},
#  {'R.A.W. Realms of Ancient War': 'Not Found'},
#  {'The Plan': '84'},
#  {'Metal Gear Solid': '93'},
#  {'The Last of Us Part II': 'tbd'},
#  {'Terra Incognita ~ Chapter One: The Descendant': 'tbd'},
#  {'Battlefield: Bad Company': '87'},
#  {'Dwarfs!?': 'tbd'},
#  {'Portal 2 Sixense Perceptual Pack': 'Not Found'},
#  {'We Were Here': '78'},
#  {"Shantae and the Pirate's Curse": '86'},
#  {'World of Tanks Blitz': '83'},
#  {'Kingdom Rush': '89'},
#  {'Warcraft 3: Reign of Chaos': '92'},
#  {'Gems of War': 'tbd'},
#  {'Shenmue I & II': '88'},
#  {'FINAL FANTASY XV WINDOWS EDITION': 'Selenium Fail'},
#  {'Sparkle 2 Evo': 'tbd'},
#  {'Minecraft: Story Mode - A Telltale Games Series': 'Selenium Fail'},
#  {'Gauntlet Slayer Edition': '71'},
#  {'Sly Cooper: Thieves in Time': '75'},
#  {'UNO': '81'},
#  {'Heavy Metal Machines': 'tbd'},
#  {'Sonic the Hedgehog 4 - Episode I': '81'},
#  {'TOXIKK': 'tbd'},
#  {'Pixel Puzzles: Japan': 'tbd'},
#  {'Sakura Clicker': 'tbd'},
#  {'EA SPORTS UFC 2': '79'},
#  {'Spyro the Dragon': '91'},
#  {'Enemy Mind': 'Selenium Fail'},
#  {'Racer 8': 'tbd'},
#  {'FINAL FANTASY X/X-2 HD Remaster': 'Not Found'},
#  {'RADical ROACH Deluxe Edition': 'Not Found'},
#  {'Q.U.B.E. 2': '76'},
#  {'Sonic the Hedgehog (1991)': 'Not Found'},
#  {"Ken Follett's The Pillars of the Earth": '78'},
#  {'Alien Shooter 2: Reloaded': 'Selenium Fail'},
#  {'Hotline Miami 2: Wrong Number Digital Comic': 'Not Found'},
#  {'Disc Jam': 'tbd'},
#  {'The Hat Man: Shadow Ward': 'tbd'},
#  {'Secret Ponchos': 'tbd'},
#  {'NEOTOKYO': 'tbd'},
#  {'Savage Lands': 'tbd'},
#  {'Just Cause 4': 'tbd'},
#  {'Tyrian 2000': 'tbd'},
#  {'LYNE': '86'},
#  {'Road Redemption': 'Selenium Fail'},
#  {'Batman: The Telltale Series': '79'},
#  {'War of the Roses': '73'},
#  {'MotorStorm Apocalypse': '77'},
#  {'Polygoneer': 'tbd'},
#  {'FIFA 13': '90'},
#  {'Legend of Mysteria RPG': 'Not Found'},
#  {'HIVESWAP: Act 1': 'Selenium Fail'},
#  {'LittleBigPlanet Karting': '73'},
#  {'WipEout HD': '89'},
#  {"Penny Arcade's On The Rain-Slick Precipice of Darkness 3": 'Not Found'},
#  {'Gang Beasts': 'tbd'},
#  {'Skate 3': '80'},
#  {'Crawl': '82'},
#  {'Getting Over It with Bennett Foddy': 'tbd'},
#  {'Airscape - The Fall of Gravity': '75'},
#  {'Beyond Good & Evil HD': '84'},
#  {'Horizon Chase Turbo': '78'},
#  {'Murder Miners': 'tbd'},
#  {'Xeodrifter': '77'},
#  {'Ace of Spades: Battle Builder': 'Not Found'},
#  {'Pillars of Eternity II: Deadfire': '88'},
#  {'Dragonsphere': 'tbd'},
#  {'Greyfox RPG': 'Not Found'},
#  {'My Friend Pedro': '81'},
#  {"America's Army: Proving Grounds": 'tbd'},
#  {'Dungeons 3': '75'},
#  {'KAO the Kangaroo: Round 2': 'tbd'},
#  {'Castlevania: Symphony of the Night': '93'},
#  {'Never Alone': 'tbd'},
#  {'GRAV': '80'},
#  {'Anomaly Korea': '86'},
#  {'Killzone 3': '84'},
#  {'Ultima IV: Quest of the Avatar': 'Not Found'},
#  {'Game Room': 'tbd'},
#  {'My Time At Portia': '75'},
#  {'Bound': '78'},
#  {'Prey: Typhon Hunter': 'Not Found'},
#  {'Fallout 76': '53'},
#  {'Car Mechanic Simulator 2014': 'tbd'},
#  {'Labyronia RPG': 'tbd'},
#  {'Zombie Driver HD': 'tbd'},
#  {'AaaaaAAaaaAAAaaAAAAaAAAAA!!! for the Awesome': 'tbd'},
#  {'Jalopy': 'tbd'},
#  {'Dead Rising 3 Apocalypse Edition': 'tbd'},
#  {'NiGHTS into dreams...': '75'},
#  {'Sacred Gold': 'tbd'},
#  {'DEAD OR ALIVE 5 Last Round: Core Fighters': 'Not Found'},
#  {'Super Killer Hornet: Resurrection': 'tbd'},
#  {'ArcheBlade': 'tbd'},
#  {'ShipLord': 'tbd'},
#  {'Heaven Island - VR MMO': 'Not Found'},
#  {'World of Warcraft': '93'},
#  {'LEGO Worlds': 'tbd'},
#  {'Floating Point': 'tbd'},
#  {'NBA 2K14': '85'},
#  {'HuniePop': 'tbd'},
#  {'Entwined': 'tbd'},
#  {'Risk of Rain 2': 'tbd'},
#  {'LIGHTNING RETURNS: FINAL FANTASY XIII': '66'},
#  {'Holy Potatoes! We’re in Space?!': 'Not Found'},
#  {'Resident Evil 2 (1-Shot Demo)': 'Not Found'},
#  {'Do Not Feed the Monkeys': 'tbd'},
#  {'Graveyard Keeper': 'tbd'},
#  {'SCP: Secret Laboratory': 'tbd'},
#  {"Spyro 2: Ripto's Rage!": 'Not Found'},
#  {'BIT.TRIP BEAT': '75'},
#  {'DRAGON QUEST XI: Echoes of an Elusive Age': '86'},
#  {'Space Farmers': 'Selenium Fail'},
#  {'Sunrider: Mask of Arcadius': 'tbd'},
#  {'Idle Champions of the Forgotten Realms': 'tbd'},
#  {'Heroes of Might and Magic 3: Complete': 'tbd'},
#  {'Odysseus Kosmos and his Robot Quest - Episode 1': 'Not Found'},
#  {'Gravilon': 'tbd'},
#  {'Full Mojo Rampage': '79'},
#  {'Thronebreaker: The Witcher Tales': '79'},
#  {"John Romero's Daikatana": 'tbd'},
#  {'RPG Maker VX Ace': 'tbd'},
#  {'Flesh Eaters': 'tbd'},
#  {'Space Pilgrim Episode I: Alpha Centauri': 'tbd'},
#  {'Treasure Adventure Game': 'tbd'},
#  {'Labyronia RPG 2': 'tbd'},
#  {'16bit Trader': 'tbd'},
#  {'Aura Kingdom': 'tbd'},
#  {'Super Crate Box': '75'},
#  {'I Have No Mouth, and I Must Scream': 'tbd'},
#  {'Ultratron': 'tbd'},
#  {'Eufloria HD': '69'},
#  {'Freebie': 'tbd'},
#  {'Cook, Serve, Delicious! 2!!': '85'},
#  {'Escape Plan': '78'},
#  {'Overcooked! 2': '77'},
#  {'Dauntless': '79'},
#  {'Forza Motorsport 3': '82'},
#  {'RIVE: Wreck, Hack, Die, Retry!': 'Not Found'},
#  {'Zen Bound 2': '80'},
#  {'Divinity: Dragon Commander': 'Selenium Fail'},
#  {'Sakura Spirit': 'tbd'},
#  {'Sonic the Hedgehog 2': '87'},
#  {'Cultist Simulator': 'tbd'},
#  {'Time Clickers': 'tbd'},
#  {'THE KING OF FIGHTERS XIII STEAM EDITION': '77'},
#  {'Far Cry New Dawn': '75'},
#  {'Hacker Evolution: Untold': 'tbd'},
#  {'Unravel Two': '77'},
#  {'BattleTech': '78'},
#  {'Sam & Max 101: Culture Shock': '81'},
#  {'We Happy Few': 'tbd'},
#  {'Electronic Super Joy': '77'},
#  {'BARRIER X': 'tbd'},
#  {'The Way of Life Free Edition': 'Not Found'},
#  {'Ghost in the Shell: Stand Alone Complex - First Assault Online': 'tbd'},
#  {'Edna & Harvey: The Breakout': 'tbd'},
#  {'Dead Rising 3': '78'},
#  {'SoulCalibur VI': '84'},
#  {'The Desolate Hope': 'Selenium Fail'},
#  {'Sam & Max 103: The Mole, the Mob and the Meatball': '74'},
#  {'Viva Piñata': '84'},
#  {'Sam & Max 102: Situation: Comedy': '79'},
#  {'Iesabel': 'tbd'},
#  {'The Mighty Quest for Epic Loot (2015)': 'Not Found'},
#  {'Dragon Age: Origins - Ultimate Edition': 'tbd'},
#  {'Worlds of Ultima: The Savage Empire': 'tbd'},
#  {"Melissa K. and the Heart of Gold Collector's Edition": 'Not Found'},
#  {'Westerado: Double Barreled': '80'},
#  {'Resistance 2': '87'},
#  {'EVGA Precision XOC': 'Not Found'},
#  {'The Saboteur': '76'},
#  {'Seven: The Days Long Gone': '68'},
#  {'iBomber Defense Pacific': '80'},
#  {'LEGO Star Wars: The Force Awakens': '78'},
#  {'DCS World': 'tbd'},
#  {'Infinifactory': 'tbd'},
#  {'Sam & Max 106: Bright Side of the Moon': '79'},
#  {'Sam & Max 105: Reality 2.0': '82'},
#  {'Bit Blaster XL': 'tbd'},
#  {'AX:EL - Air XenoDawn': 'Not Found'},
#  {'Crackdown 3': 'tbd'},
#  {'SYNTHETIK': 'tbd'},
#  {'AirMech': 'tbd'},
#  {'Refunct': 'tbd'},
#  {'Endless Space': '80'},
#  {'Talisman: Prologue': 'Selenium Fail'},
#  {'Another World – 20th Anniversary Edition': '80'},
#  {'Spirits': '78'},
#  {'Rare Replay': '84'},
#  {'Galaxy on Fire 2 Full HD': '63'},
#  {'Mechanic Escape': 'tbd'},
#  {'Evolve': '97'},
#  {'ROME: Total War': '76'},
#  {'Ravensword: Shadowlands': '76'},
#  {'Stellar 2D': 'tbd'},
#  {'Cobi Treasure Deluxe': 'tbd'},
#  {'Agent Awesome': 'tbd'},
#  {'Eufloria': 'tbd'},
#  {'Planets Under Attack': 'tbd'},
#  {'Dragon Ball Xenoverse': '75'},
#  {'Euro Truck Simulator': '79'},
#  {'Blackwake': 'tbd'},
#  {'Train Simulator': '84'},
#  {'ACE - Arena: Cyber Evolution': 'Selenium Fail'},
#  {'Crash Team Racing Nitro-Fueled': '84'},
#  {'The Red Strings Club': '80'},
#  {'Majesty 2 Collection': 'tbd'},
#  {'Infestation: The New Z': 'tbd'},
#  {'DeathSpank': '77'},
#  {"Uriel's Chasm": 'tbd'},
#  {'Max: The Curse of Brotherhood': 'tbd'},
#  {'Sheltered': 'tbd'},
#  {'Vanguard Princess': 'tbd'},
#  {'QUAKE Mission Pack 1: Scourge of Armagon': 'tbd'},
#  {'We Were Here Too': '69'},
#  {'Sam & Max 205: What&#146;s New Beelzebub?': 'Not Found'},
#  {'Commando Jack': 'tbd'},
#  {'Need For Speed Carbon': '78'},
#  {'Shadow Complex Remastered': '80'},
#  {'11-11 Memories Retold': '77'},
#  {'Wolfenstein: Youngblood': '63'},
#  {'Distrust': '77'},
#  {'Voxelized': 'tbd'},
#  {'KickBeat': 'tbd'},
#  {'PARTICLE MACE': '87'},
#  {'QUAKE Mission Pack 2: Dissolution of Eternity': 'tbd'},
#  {'Turbo Pug': 'tbd'},
#  {'Carmageddon TDR 2000': '48'},
#  {'QUAKE II Mission Pack: The Reckoning': 'tbd'},
#  {'Last Man Standing': 'tbd'},
#  {'Metal Gear Solid 3: Snake Eater': '91'},
#  {'Nioh: Complete Edition / 仁王 Complete Edition': '84'},
#  {'Estranged: Act II': 'tbd'},
#  {"Clive Barker's Jericho": '63'},
#  {'Battle Chef Brigade': '81'},
#  {'Sportsfriends': '82'},
#  {'SPORE Creepy & Cute Parts Pack': 'Selenium Fail'},
#  {'Divinity: Original Sin 2 - Definitive Edition': 'Not Found'},
#  {'Deep Dungeons of Doom': '77'},
#  {'Savant - Ascent': 'tbd'},
#  {"Yoku's Island Express": '82'},
#  {"Oddworld: Munch's Oddysee": '80'},
#  {'Another World': '75'},
#  {'Banjo-Kazooie': '92'},
#  {'SEGA Bass Fishing': '76'},
#  {'QuestRun': 'tbd'},
#  {'Spartacus Legends': '50'},
#  {'Midnight Club: LA': '82'},
#  {'Soul Gambler': 'tbd'},
#  {'The Jackbox Party Pack 2': '77'},
#  {'Battle Chasers: Nightwar': '80'},
#  {'FIFA 10': '91'},
#  {'The Legend of Zelda: Ocarina of Time': '99'},
#  {'Shadows on the Vatican Act I: Greed': 'tbd'},
#  {'Bloodbath Kavkaz': 'tbd'},
#  {'Grimoire: Manastorm': 'tbd'},
#  {'One Piece Pirate Warriors 3': '76'},
#  {'Mr. Shifty': '77'},
#  {'Drawn To Death': '56'},
#  {'One Way Heroics': 'tbd'},
#  {'DogFighter': 'Selenium Fail'},
#  {'Saints Row IV: Re-Elected': '75'},
#  {'Tales of Symphonia': '86'},
#  {'Ultimate Marvel vs. Capcom 3': '77'},
#  {'Numba Deluxe': 'tbd'},
#  {'Mortal Kombat vs. DC Universe': '76'},
#  {'PlayStation VR Worlds': '59'},
#  {'Princess Remedy In A Heap of Trouble': 'tbd'},
#  {'Leviathan: Warships': '70'},
#  {'Robot Roller-Derby Disco Dodgeball': 'tbd'},
#  {'Peggle 2': '89'},
#  {'Star Chronicles: Delta Quadrant': 'tbd'},
#  {'Chip': 'tbd'},
#  {'Metal Slug X': '85'},
#  {'Geometry Dash': 'tbd'},
#  {'New kind of adventure': 'tbd'},
#  {'Tiny Bridge: Ratventure': 'Not Found'},
#  {'Pixel Puzzles: UndeadZ': 'tbd'},
#  {'Castlevania: Lords of Shadow - Mirror of Fate': 'tbd'},
#  {'Rock of Ages 2: Bigger & Boulder': '79'},
#  {'Regions Of Ruin': 'tbd'},
#  {'Moonbase Alpha': 'tbd'},
#  {'Battlefield 1943': '83'},
#  {'Forza Motorsport 4': '91'},
#  {'Ampu-Tea': 'tbd'},
#  {'Dandara': '81'},
#  {'Destiny Warriors RPG': 'tbd'},
#  {'NEED FOR SPEED THE RUN': 'tbd'},
#  {'The Dark Pictures: Man of Medan': '75'},
#  {'Beat Saber': '93'},
#  {'Gothic 3: Forsaken Gods Enhanced Edition': 'Not Found'},
#  {'NEKOPARA Vol. 0': 'tbd'},
#  {'Call to Arms': 'tbd'},
#  {'Hurtworld': 'tbd'},
#  {'The Council': '79'},
#  {'Interplanetary': '84'},
#  {'Marble Mayhem: Fragile Ball': 'Not Found'},
#  {'Secret Of Magia': 'tbd'},
#  {'DOOM Eternal': 'tbd'},
#  {'Pressured': 'tbd'},
#  {'Splatter - Zombie Apocalypse': 'Not Found'},
#  {"Spooky's Jump Scare Mansion": 'tbd'},
#  {'Iron Snout': 'tbd'},
#  {'MDK': '83'},
#  {'Tooth and Tail': '80'},
#  {'Carmageddon: Max Damage': 'tbd'},
#  {'Interplanetary: Enhanced Edition': 'tbd'},
#  {'Platypus 2': 'Not Found'},
#  {'Streets of Rage 2': '84'},
#  {'Stargunner': 'tbd'},
#  {'Rolling Sun': 'tbd'},
#  {'Subterrain': 'tbd'},
#  {'Umbrella Corps /Biohazard Umbrella Corps': 'Not Found'},
#  {'Paranautical Activity: Deluxe Atonement Edition': 'Not Found'},
#  {'Normality': 'tbd'},
#  {'Distance': '75'},
#  {'Hohokum': '75'},
#  {'Breach & Clear': 'tbd'},
#  {'Remnant: From the Ashes': '76'},
#  {'EA SPORTS UFC 3': '75'},
#  {'Business Tour': 'tbd'},
#  {'Golf With Your Friends': 'tbd'},
#  {'Town of Salem': 'tbd'},
#  {'Shadowverse CCG': 'Not Found'},
#  {'Hard Reset': 'tbd'},
#  {'Zombie Shooter 2': 'Selenium Fail'},
#  {'SUPER DISTRO': 'tbd'},
#  {'Super Sanctum TD': 'tbd'},
#  {'Crystals of Time': 'tbd'},
#  {'Tropico Reloaded': 'tbd'},
#  {'Shoppe Keep': 'tbd'},
#  {'The Norwood Suite': 'tbd'},
#  {'Viscera Cleanup Detail': 'tbd'},
#  {'Frederic: Resurrection of Music': '75'},
#  {'Frozen Free Fall: Snowball Fight': 'tbd'},
#  {"LEGO Marvel's Avengers": 'tbd'},
#  {'Hardware: Rivals': '56'},
#  {'Guitar Hero Live': '80'},
#  {'Baba Is You': '87'},
#  {'Wasteland 2': '87'},
#  {'Battlepaths': 'tbd'},
#  {'Codename CURE': 'tbd'},
#  {'Craft The World': 'tbd'},
#  {'Need for Speed: Underground 2': '82'},
#  {'Zombie Shooter': 'tbd'},
#  {'Void Bastards': 'Selenium Fail'},
#  {'Double Dragon Neon': 'tbd'},
#  {'Velocity Ultra': '87'},
#  {'Tinboy': 'tbd'},
#  {'Full Metal Furies': '85'},
#  {'Hexcells': 'tbd'},
#  {'Knytt Underground': '79'},
#  {'Warsow': 'tbd'},
#  {'Figment': '75'},
#  {'8-Bit Bayonetta': 'tbd'},
#  {'Muramasa Rebirth': '78'},
#  {'Flatout 3: Chaos & Destruction': '23'},
#  {'Hustle Kings': '81'},
#  {'OutDrive': 'tbd'},
#  {'Space Channel 5: Part 2': '78'},
#  {'SSX': '93'},
#  {'Precipice of Darkness, Episode One': 'Not Found'},
#  {"Penny Arcade's On the Rain-Slick Precipice of Darkness 4": 'Not Found'},
#  {'12 Labours of Hercules II: The Cretan Bull': 'tbd'},
#  {'Renowned Explorers: International Society': '72'},
#  {'Dragon Fin Soup': 'tbd'},
#  {'Fractal: Make Blooms Not War': '84'},
#  {'Millie': 'tbd'},
#  {'Super Mustache': 'tbd'},
#  {'Ampersand': 'Selenium Fail'},
#  {'HunieCam Studio': 'tbd'},
#  {'Slipstream 5000': 'tbd'},
#  {'Peggle': '91'},
#  {'Strife': 'tbd'},
#  {'Gorogoa': '84'},
#  {'Tomb Raider II (2011)': 'Not Found'},
#  {'Sparkle 3 Genesis': 'tbd'},
#  {'MechWarrior Online': '68'},
#  {'Cult of the Wind': 'tbd'},
#  {'Data Hacker: Initiation': 'tbd'},
#  {'The Ship': '79'},
#  {'Epigenesis': 'tbd'},
#  {'Gun Rocket': 'tbd'},
#  {'flOw': '91'},
#  {'Orborun': '81'},
#  {'Snuggle Truck': '89'},
#  {"A KING'S TALE: FINAL FANTASY XV": 'tbd'},
#  {'MANDAGON': 'tbd'},
#  {'Puppeteer': '80'},
#  {'Rush Bros.': 'tbd'},
#  {'Supraball': 'tbd'},
#  ...]

# %%
raw_scores_df = pd.read_json('metacritic_scores.json', lines=True)
raw_scores_df
# Out:
#       The Elder Scrolls V: Skyrim Half-Life 2: Lost Coast  Metro 2033  \
# 0                            84.0                     NaN         NaN
# 1                             NaN                     tbd         NaN
# 2                             NaN                     NaN        90.0
# 3                             NaN                     NaN         NaN
# 4                             NaN                     NaN         NaN
# ...                           ...                     ...         ...
# 1395                          NaN                     NaN         NaN
# 1396                          NaN                     NaN         NaN
# 1397                          NaN                     NaN         NaN
# 1398                          NaN                     NaN         NaN
# 1399                          NaN                     NaN         NaN
#
#       Warframe     God of War  Red Dead Redemption 2 Horizon Zero Dawn  \
# 0          NaN            NaN                    NaN               NaN
# 1          NaN            NaN                    NaN               NaN
# 2          NaN            NaN                    NaN               NaN
# 3         86.0            NaN                    NaN               NaN
# 4          NaN  Selenium Fail                    NaN               NaN
# ...        ...            ...                    ...               ...
# 1395       NaN            NaN                    NaN               NaN
# 1396       NaN            NaN                    NaN               NaN
# 1397       NaN            NaN                    NaN               NaN
# 1398       NaN            NaN                    NaN               NaN
# 1399       NaN            NaN                    NaN               NaN
#
#      Half-Life 2: Deathmatch Batman: Arkham Knight Uncharted 4: A Thief’s End  \
# 0                        NaN                   NaN                        NaN
# 1                        NaN                   NaN                        NaN
# 2                        NaN                   NaN                        NaN
# 3                        NaN                   NaN                        NaN
# 4                        NaN                   NaN                        NaN
# ...                      ...                   ...                        ...
# 1395                     NaN                   NaN                        NaN
# 1396                     NaN                   NaN                        NaN
# 1397                     NaN                   NaN                        NaN
# 1398                     NaN                   NaN                        NaN
# 1399                     NaN                   NaN                        NaN
#
#       ... Super Mario Bros. 3 NBA 2K18  Bleed  Call of Cthulhu Wargroove  \
# 0     ...                 NaN      NaN    NaN              NaN       NaN
# 1     ...                 NaN      NaN    NaN              NaN       NaN
# 2     ...                 NaN      NaN    NaN              NaN       NaN
# 3     ...                 NaN      NaN    NaN              NaN       NaN
# 4     ...                 NaN      NaN    NaN              NaN       NaN
# ...   ...                 ...      ...    ...              ...       ...
# 1395  ...                 NaN      NaN    NaN              NaN       NaN
# 1396  ...                 NaN      NaN    NaN              NaN       NaN
# 1397  ...                 NaN      NaN    NaN              NaN       NaN
# 1398  ...                 NaN      NaN    NaN              NaN       NaN
# 1399  ...                 NaN      NaN    NaN              NaN       NaN
#
#       THE KING OF FIGHTERS 2002 Depression Quest The Tower Of Elements  \
# 0                           NaN              NaN                   NaN
# 1                           NaN              NaN                   NaN
# 2                           NaN              NaN                   NaN
# 3                           NaN              NaN                   NaN
# 4                           NaN              NaN                   NaN
# ...                         ...              ...                   ...
# 1395                        tbd              NaN                   NaN
# 1396                        NaN              tbd                   NaN
# 1397                        NaN              NaN                   tbd
# 1398                        NaN              NaN                   NaN
# 1399                        NaN              NaN                   NaN
#
#       Space Pilgrim Episode IV: Sol The Beatles: Rock Band
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 3                               NaN                    NaN
# 4                               NaN                    NaN
# ...                             ...                    ...
# 1395                            NaN                    NaN
# 1396                            NaN                    NaN
# 1397                            NaN                    NaN
# 1398                            tbd                    NaN
# 1399                            NaN                   89.0
#
# [1400 rows x 1400 columns]

# %%
df2 = df.copy(deep=True)

# %%
def reshape_metacritic_df(filename):
    '''
    '''
    metacritic_scores = pd.read_json(filename, lines=True)
    metacritic_scores.set_index([metacritic_scores.columns], inplace=True)
    return pd.DataFrame(np.diag(metacritic_scores), index=metacritic_scores.index, columns=['metacritic'])

def extract_selenium_fails(filename):
    '''
    Input:
        filename: file name for a json containing games and their respective metacritic scores
    Retruns:
        numpy array containing only the games that do not have selenium scores  
    '''
    with open(filename, 'r') as file:
            meta_scores = [json.loads(f) for f in file]
    
    fails = []
    for game in meta_scores:
        for k, v in game.items():
            if v == 'Not Found' or v == 'Selenium Fail':
                fails.append(k)

    return np.array(fails)

def fill_metacritic(df, filename, column):
    '''
    '''  
    # create a single column df with all the scraped data found on the diagonal
    scores_column = reshape_metacritic_df(filename)

    # get the games that did not scrape the first time to try again later.
    selenium_fails = extract_selenium_fails(filename)
    
    # fill the missing results from the scraped scores by index
    df.set_index('name', inplace=True)
    df['metacritic'] = df[column].fillna(scores_column[column])
    return df, selenium_fails

# %%
df2
# Out:
#            id                         name  rating  \
# 0        3498           Grand Theft Auto V    4.48
# 1        4200                     Portal 2    4.61
# 2        3328     The Witcher 3: Wild Hunt    4.68
# 3        5679  The Elder Scrolls V: Skyrim    4.39
# 4       12020                Left 4 Dead 2    4.08
# ...       ...                          ...     ...
# 11291   33076                     Hexxagon    0.00
# 11294    5899               Temple Run: Oz    0.00
# 11295   32329                  Nitemare-3D    0.00
# 11296  394092                      Bemuzed    0.00
# 11297  299546               Swing the Ball    4.12
#
#                                                  ratings    released  \
# 0      [{'id': 5, 'title': 'exceptional', 'count': 16...  2013-09-17
# 1      [{'id': 5, 'title': 'exceptional', 'count': 16...  2011-04-19
# 2      [{'id': 5, 'title': 'exceptional', 'count': 20...  2015-05-18
# 3      [{'id': 5, 'title': 'exceptional', 'count': 10...  2011-11-11
# 4      [{'id': 4, 'title': 'recommended', 'count': 76...  2009-11-17
# ...                                                  ...         ...
# 11291  [{'id': 4, 'title': 'recommended', 'count': 4,...  1993-01-01
# 11294  [{'id': 4, 'title': 'recommended', 'count': 2,...  2013-03-05
# 11295  [{'id': 1, 'title': 'skip', 'count': 2, 'perce...  1994-01-01
# 11296  [{'id': 5, 'title': 'exceptional', 'count': 5,...  2019-11-22
# 11297  [{'id': 4, 'title': 'recommended', 'count': 7,...  2019-02-20
#
#        metacritic  ratings_count                   genres
# 0            96.0           2758        [Action, Shooter]
# 1            95.0           2405        [Shooter, Puzzle]
# 2            93.0           2552                    [RPG]
# 3             NaN           2015            [Action, RPG]
# 4            89.0           1431        [Action, Shooter]
# ...           ...            ...                      ...
# 11291         NaN              4  [Strategy, Board Games]
# 11294         NaN              4      [Action, Adventure]
# 11295         NaN              4        [Action, Shooter]
# 11296         NaN              4     [Puzzle, Platformer]
# 11297         NaN              6          [Casual, Indie]
#
# [10509 rows x 8 columns]

# %%
df2, fails = fill_metacritic(df2, 'metacritic_scores.json', 'metacritic')
df2
# Out:
#                                  id  rating  \
# name
# Grand Theft Auto V             3498    4.48
# Portal 2                       4200    4.61
# The Witcher 3: Wild Hunt       3328    4.68
# The Elder Scrolls V: Skyrim    5679    4.39
# Left 4 Dead 2                 12020    4.08
# ...                             ...     ...
# Hexxagon                      33076    0.00
# Temple Run: Oz                 5899    0.00
# Nitemare-3D                   32329    0.00
# Bemuzed                      394092    0.00
# Swing the Ball               299546    4.12
#
#                                                                        ratings  \
# name
# Grand Theft Auto V           [{'id': 5, 'title': 'exceptional', 'count': 16...
# Portal 2                     [{'id': 5, 'title': 'exceptional', 'count': 16...
# The Witcher 3: Wild Hunt     [{'id': 5, 'title': 'exceptional', 'count': 20...
# The Elder Scrolls V: Skyrim  [{'id': 5, 'title': 'exceptional', 'count': 10...
# Left 4 Dead 2                [{'id': 4, 'title': 'recommended', 'count': 76...
# ...                                                                        ...
# Hexxagon                     [{'id': 4, 'title': 'recommended', 'count': 4,...
# Temple Run: Oz               [{'id': 4, 'title': 'recommended', 'count': 2,...
# Nitemare-3D                  [{'id': 1, 'title': 'skip', 'count': 2, 'perce...
# Bemuzed                      [{'id': 5, 'title': 'exceptional', 'count': 5,...
# Swing the Ball               [{'id': 4, 'title': 'recommended', 'count': 7,...
#
#                                released metacritic  ratings_count  \
# name
# Grand Theft Auto V           2013-09-17         96           2758
# Portal 2                     2011-04-19         95           2405
# The Witcher 3: Wild Hunt     2015-05-18         93           2552
# The Elder Scrolls V: Skyrim  2011-11-11         84           2015
# Left 4 Dead 2                2009-11-17         89           1431
# ...                                 ...        ...            ...
# Hexxagon                     1993-01-01        NaN              4
# Temple Run: Oz               2013-03-05        NaN              4
# Nitemare-3D                  1994-01-01        NaN              4
# Bemuzed                      2019-11-22        NaN              4
# Swing the Ball               2019-02-20        NaN              6
#
#                                               genres
# name
# Grand Theft Auto V                 [Action, Shooter]
# Portal 2                           [Shooter, Puzzle]
# The Witcher 3: Wild Hunt                       [RPG]
# The Elder Scrolls V: Skyrim            [Action, RPG]
# Left 4 Dead 2                      [Action, Shooter]
# ...                                              ...
# Hexxagon                     [Strategy, Board Games]
# Temple Run: Oz                   [Action, Adventure]
# Nitemare-3D                        [Action, Shooter]
# Bemuzed                         [Puzzle, Platformer]
# Swing the Ball                       [Casual, Indie]
#
# [10509 rows x 7 columns]

# %%
type(df2)
# Out:
# tuple

# %%
df.reset_index(inplace=True)

# %%
df.drop(columns=['index'], inplace=True)

# %%
# Out:
#                                 name      id  rating  \
# 0                 Grand Theft Auto V    3498    4.48
# 1                           Portal 2    4200    4.61
# 2           The Witcher 3: Wild Hunt    3328    4.68
# 3        The Elder Scrolls V: Skyrim    5679    4.39
# 4                      Left 4 Dead 2   12020    4.08
# ...                              ...     ...     ...
# 11099  Sonic Boom: Shattered Crystal   27504    0.00
# 11100                 Temple Run: Oz    5899    0.00
# 11101                    Nitemare-3D   32329    0.00
# 11102                        Bemuzed  394092    0.00
# 11103                 Swing the Ball  299546    4.12
#
#                                                  ratings    released  \
# 0      [{'id': 5, 'title': 'exceptional', 'count': 16...  2013-09-17
# 1      [{'id': 5, 'title': 'exceptional', 'count': 16...  2011-04-19
# 2      [{'id': 5, 'title': 'exceptional', 'count': 20...  2015-05-18
# 3      [{'id': 5, 'title': 'exceptional', 'count': 10...  2011-11-11
# 4      [{'id': 4, 'title': 'recommended', 'count': 76...  2009-11-17
# ...                                                  ...         ...
# 11099  [{'id': 1, 'title': 'skip', 'count': 3, 'perce...  2014-11-11
# 11100  [{'id': 4, 'title': 'recommended', 'count': 2,...  2013-03-05
# 11101  [{'id': 1, 'title': 'skip', 'count': 2, 'perce...  1994-01-01
# 11102  [{'id': 5, 'title': 'exceptional', 'count': 5,...  2019-11-22
# 11103  [{'id': 4, 'title': 'recommended', 'count': 7,...  2019-02-20
#
#        metacritic  ratings_count                genres
# 0            96.0           2758     [Action, Shooter]
# 1            95.0           2405     [Shooter, Puzzle]
# 2            93.0           2552                 [RPG]
# 3             NaN           2015         [Action, RPG]
# 4            89.0           1431     [Action, Shooter]
# ...           ...            ...                   ...
# 11099         NaN              4                    []
# 11100         NaN              4   [Action, Adventure]
# 11101         NaN              4     [Action, Shooter]
# 11102         NaN              4  [Puzzle, Platformer]
# 11103         NaN              6       [Casual, Indie]
#
# [11104 rows x 8 columns]

# %%
with open('metacritic_scores.json', 'r') as file:
            meta_scores = [json.loads(f) for f in file]
    
fails = []
for game in meta_scores:
    for k, v in game.items():
        if v == 'Not Found' or v == 'Selenium Fail':
            fails.append(k)
        
np.array(fails)
# Out:
# array(['God of War', 'Horizon Zero Dawn', 'Batman: Arkham Knight',
#        'Uncharted 4: A Thief’s End', 'Assassin’s Creed IV Black Flag',
#        'PlayerUnknown’s Battlegrounds', 'Paladins', 'NieR:Automata',
#        'Half-Life: Opposing Force', 'Tom Clancy’s The Division',
#        'Serious Sam Fusion 2017 (beta)', 'Watch Dogs 2',
#        'Ratchet & Clank (2016)', 'Battlefield 4',
#        'Borderlands Game of the Year Enhanced',
#        'Sekiro: Shadows Die Twice', 'LEGO The Hobbit',
#        'STAR WARS Battlefront', 'God of War III Remastered',
#        'Fortnite: Save The World',
#        'Resident Evil Revelations 2 / Biohazard Revelations 2',
#        'The Long Dark', 'Ricochet', 'Minecraft', 'H1Z1: King of the Kill',
#        'Forza Horizon 4', 'Sunset Overdrive', 'Besiege',
#        'The Ship: Single Player', 'Never Alone (Kisima Ingitchuna)',
#        'ORION: Prelude', 'No Time To Explain Remastered',
#        'Tom Clancy’s Splinter Cell Blacklist', 'Really Big Sky',
#        'Crash Bandicoot 2: Cortex Strikes Back', 'Crazy Taxi (1999)',
#        'Resident Evil 7 / Biohazard 7 Teaser: Beginning Hour',
#        "Sam & Max 303: They Stole Max's Brain!",
#        'Back to the Future: Ep 4 - Double Visions',
#        'Back to the Future: Ep 3 - Citizen Brown',
#        'Back to the Future: Ep 2 - Get Tannen!',
#        'Sam & Max 305: The City That Dares Not Sleep',
#        'Sam & Max 304: Beyond the Alley of the Dolls',
#        'Sam & Max 302: The Tomb of Sammun-Mak',
#        'Sam & Max 301: The Penal Zone', 'God of War II', 'Crysis 2',
#        'EA SPORTS FIFA 16', 'Into the Breach', 'Gorky 17', 'Crossout',
#        'Sonic CD', "Mirror's Edge Catalyst", 'Battlefield V',
#        'Eets Munchies', 'I’m not a Monster',
#        'Resident Evil 0 / biohazard 0 HD REMASTER', 'Black Squad',
#        'Catherine',
#        "Broken Sword: Shadow of the Templars - The Director's Cut",
#        'Emily is Away', 'Just Cause 2: Multiplayer Mod',
#        'Grand Theft Auto 2 (1999)', 'Knowledge is Power', 'Serena',
#        'Legend of Grimrock 2', 'Tom Clancy’s The Division 2',
#        'Broken Sword 2 - the Smoking Mirror: Remastered',
#        'Quake II (1997)', 'A Plague Tale: Innocence',
#        'Grand Theft Auto (1998)', 'God of War (2005)',
#        'Resident Evil (2002)', 'Knights of Pen and Paper +1 Edition',
#        'Painkiller: Black Edition', 'SimCity 4 Deluxe Edition',
#        'Overgrowth', 'Argo', 'Type:Rider', 'State of Decay: YOSE',
#        'RimWorld', 'State of Decay 2',
#        'Tomb Raider IV: The Last Revelation',
#        'App Game Kit: Easy Game Development', 'Return Of The Obra Dinn',
#        'Sid Meier’s Ace Patrol', 'PAC-MAN Championship Edition DX+',
#        'Sid Meier’s Ace Patrol: Pacific Skies',
#        'Transmissions: Element 120', 'Skyforge',
#        'Tomb Raider V: Chronicles', 'Source Filmmaker',
#        'Arma 2: DayZ Mod', 'Tree of Savior (English Ver.)',
#        'Assassin’s Creed Chronicles: China', 'Blockstorm',
#        'Darwin Project - Open Beta', 'Hacker Evolution',
#        "Broken Sword 5 - the Serpent's Curse", 'Timberman',
#        'Bloodstained: Ritual of the Night',
#        'Warhammer 40,000: Eternal Crusade', 'Star Saviors', 'Katana ZERO',
#        'R.A.W. Realms of Ancient War', 'Portal 2 Sixense Perceptual Pack',
#        'FINAL FANTASY XV WINDOWS EDITION',
#        'Minecraft: Story Mode - A Telltale Games Series', 'Enemy Mind',
#        'FINAL FANTASY X/X-2 HD Remaster', 'RADical ROACH Deluxe Edition',
#        'Sonic the Hedgehog (1991)', 'Alien Shooter 2: Reloaded',
#        'Hotline Miami 2: Wrong Number Digital Comic', 'Road Redemption',
#        'Legend of Mysteria RPG', 'HIVESWAP: Act 1',
#        "Penny Arcade's On The Rain-Slick Precipice of Darkness 3",
#        'Ace of Spades: Battle Builder', 'Greyfox RPG',
#        'Ultima IV: Quest of the Avatar', 'Prey: Typhon Hunter',
#        'DEAD OR ALIVE 5 Last Round: Core Fighters',
#        'Heaven Island - VR MMO', 'Holy Potatoes! We’re in Space?!',
#        'Resident Evil 2 (1-Shot Demo)', "Spyro 2: Ripto's Rage!",
#        'Space Farmers', 'Odysseus Kosmos and his Robot Quest - Episode 1',
#        'RIVE: Wreck, Hack, Die, Retry!', 'Divinity: Dragon Commander',
#        'The Way of Life Free Edition', 'The Desolate Hope',
#        'The Mighty Quest for Epic Loot (2015)',
#        "Melissa K. and the Heart of Gold Collector's Edition",
#        'EVGA Precision XOC', 'AX:EL - Air XenoDawn', 'Talisman: Prologue',
#        'ACE - Arena: Cyber Evolution',
#        'Sam & Max 205: What&#146;s New Beelzebub?',
#        'SPORE Creepy & Cute Parts Pack',
#        'Divinity: Original Sin 2 - Definitive Edition', 'DogFighter',
#        'Tiny Bridge: Ratventure',
#        'Gothic 3: Forsaken Gods Enhanced Edition',
#        'Marble Mayhem: Fragile Ball', 'Splatter - Zombie Apocalypse',
#        'Platypus 2', 'Umbrella Corps /Biohazard Umbrella Corps',
#        'Paranautical Activity: Deluxe Atonement Edition',
#        'Shadowverse CCG', 'Zombie Shooter 2', 'Void Bastards',
#        'Precipice of Darkness, Episode One',
#        "Penny Arcade's On the Rain-Slick Precipice of Darkness 4",
#        'Ampersand', 'Tomb Raider II (2011)',
#        'The Typing of The Dead: Overkill', 'Pumped BMX +',
#        'The Uncertain: Episode 1 - The Last Quiet Day', 'Dead or Alive 5',
#        'ShareX', 'Please, Don’t Touch Anything', '1954 Alcatraz',
#        'Shutshimi', 'Aliens Versus Predator (1999)',
#        "Bear With Me - Collector's Edition", 'WARMACHINE: Tactics',
#        'Sinister City', "Penguins Arena: Sedna's World", 'Pathologic 2',
#        'Riders of Icarus', 'Forge of Gods (RPG)', 'Nyctophobia',
#        'Assassin’s Creed Liberation HD', 'Forza Motorsport 2',
#        'Soul Calibur V', 'WipEout 2048', 'Construct 2', 'Anarchy Arcade',
#        'Lugaru HD', 'God of War: Ghost of Sparta', 'Lup',
#        'Call of Duty: Modern Warfare (2019)', 'Unknown Battle', 'Panzar',
#        'HeXen: Beyond Heretic', 'H1Z1: Just Survive',
#        'Sometimes: Success Requires Sacrifice', 'Blair Witch',
#        'Spy Chameleon - RGB Agent', 'Secrets of Rætikon',
#        'Sun Blast: Star Fighter', 'Perfect Dark Zero',
#        'Bendy and the Ink Machine',
#        'Maldita Castilla EX - Cursed Castile', 'Startopia', 'Teenagent',
#        'S.K.I.L.L. - Special Force 2 (Shooter)', 'Gnomoria',
#        'Escape Plan (2017)', 'Space Pilgrim Episode II: Epsilon Indi',
#        "The Legend of Zelda: Link's Awakening (2019)", 'Gran Turismo 6',
#        'Forged Battalion', 'Steel & Steam: Episode 1', 'Genital Jousting',
#        'Greedfall', 'Banjo Kazooie: N n B', 'Sins Of The Demon RPG',
#        'Tony Hawk’s Pro Skater HD', 'Hexen 2', 'Majesty Gold HD',
#        'Shadowgrounds: Survivor', 'Ghostbusters: The Video Game',
#        'KINGDOM HEARTS FINAL MIX', 'Battle Ranch: Pigs vs Plants',
#        'The Witcher 3: Game of the Year',
#        'Freedom Force vs. the Third Reich',
#        'The Journey Down: Chapter Three', 'Two Worlds II Castle Defense',
#        'Ben There, Dan That!', 'Perfect Dark', "Uriel's Chasm 2: את",
#        'Puddle', 'Precipice of Darkness, Episode Two', 'Loot Hero DX',
#        'EasyAntiCheat eSports'], dtype='<U57')
